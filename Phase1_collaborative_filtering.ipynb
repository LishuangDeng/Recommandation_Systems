# %%
# import packages
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import IsolationForest
from sklearn.metrics import silhouette_score
from sklearn.metrics.pairwise import cosine_similarity
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise.model_selection import cross_validate
from surprise import accuracy
from sklearn.cluster import KMeans
from mlxtend.frequent_patterns import apriori, association_rules,fpgrowth

import datetime
import os

# %%
# define folder where your data is stored
directory = 'C:/D_disk/02_Learning/27_Ughent_courses/32_Master_dissertation/Melika_Git/Data'

# get all files in directory
all_files = os.listdir(directory)
all_files
# Out:
# ['film_links_by_genre.csv',
#  'README.md',
#  'reviews_10000.csv',
#  'reviews_4000.csv',
#  'usernames.csv']

# %%
# read files
film = pd.read_csv('C:/D_disk/02_Learning/27_Ughent_courses/32_Master_dissertation/Melika_Git/Data/film_links_by_genre.csv')
reviews = pd.read_csv('C:/D_disk/02_Learning/27_Ughent_courses/32_Master_dissertation/Melika_Git/Data/reviews_10000.csv')

# %%
# clean reviews

# check reviews null value
print(reviews.isnull().sum())

# show
reviews.head(5)
# Out:
# user_id     0
# film        0
# comment    88
# date        0
# rating      0
# dtype: int64
#             user_id                 film  \
# 0  /film_addiction/               quills
# 1  /film_addiction/  children-of-divorce
# 2  /film_addiction/              morocco
# 3  /film_addiction/    design-for-living
# 4       /dustymoth/                  jfk
#
#                                              comment         date rating
# 0  Watched this trash only because Joaquin Phoeni...  03 Sep 2024      ★
# 1  This was the first Gary Coopers movie that I w...  25 Aug 2024  ★★★★★
# 2  Spoilers !A classic without a doubt. Dietrich ...  25 Aug 2024    ★★★
# 3  Absolutely loved this movie ! The humor and th...  25 Aug 2024  ★★★★★
# 4  It was so long that I stopped caring who kille...  22 Oct 2024     ★★

# %%
# Transfer reviews date time
# Check for out-of-bounds dates
invalid_dates = reviews[~reviews['date'].str.match(r'^\d{2} \w{3} \d{4}$')]

# Attempt to convert the 'date' column to datetime, while handling errors
reviews['date'] = pd.to_datetime(reviews['date'], errors='coerce')

# Check for rows with NaT (Not a Time) which indicates failed conversions
invalid_date_rows = reviews[reviews['date'].isna()]

# Optionally, drop or fill NaT values
reviews = reviews.dropna(subset=['date'])

# %%
print('The first date:',reviews['date'].max())
print('The last date:',reviews['date'].min())
# Out:
# The first date: 2024-11-08 00:00:00
# The last date: 1776-07-04 00:00:00

# %%
# remove the irreliable date   letterboxed.com was found in 2011-10-24
reviews = reviews[reviews['date']>='2011-10-24 00:00:00']

# %%
# Transfer the rating
# Define a function to convert star ratings to numerical values
def convert_rating(rating):
    # Remove any fractions from the ratings
    if '½' in rating:
        return (rating.count('★') + 0.5)  # Count stars and add 0.5 for half star
    return rating.count('★')  # Count stars

# Apply the conversion function to the 'rating' column
reviews['rating'] = reviews['rating'].apply(convert_rating)

# %%
# get the rating distribution
reviews['rating'].value_counts()
# Out:
# rating
# 4.0    172513
# 3.0    131675
# 3.5    131198
# 5.0    119327
# 4.5     77958
# 0.0     68549
# 2.5     63154
# 2.0     55145
# 1.0     24051
# 1.5     23295
# 0.5     14290
# Name: count, dtype: int64

# %%
# split train and test
date = reviews[['user_id','date']].drop_duplicates().groupby('user_id')['date'].count().reset_index().sort_values(by=['date']).rename(columns={'date':'num_date'})
#only keep the number of watched date >2
date = date[date['num_date']>2]
reviews = date.merge(reviews, how='inner',on='user_id')
reviews.head()
# Out:
#              user_id  num_date                    film  \
# 0  /camomila_loures/         3                deadpool
# 1  /camomila_loures/         3  a-boy-called-christmas
# 2  /camomila_loures/         3        black-widow-2021
# 3  /camomila_loures/         3                clueless
# 4  /camomila_loures/         3                coraline
#
#                                comment       date  rating
# 0                           Filme ruim 2024-08-16     2.0
# 1                     Odeio esse filme 2024-08-16     1.0
# 2                     AMOOOOOOO DEMAIS 2024-08-16     5.0
# 3  É meio chatinho mas até que é legal 2024-08-16     3.0
# 4                            Amo muito 2024-08-16     5.0

# %%
# Cleaning the userid
reviews['user_id']=reviews['user_id'].str.replace('/','')

# last_watched 
last_watched = reviews.groupby('user_id')['date'].max().reset_index()
last_watched_df = reviews[['user_id','date','film','rating']].merge(last_watched,how='inner',on=['user_id','date'])

# training set
merged_df = reviews.merge(last_watched_df[['user_id', 'date', 'film']], on=['user_id', 'date', 'film'], how='left', indicator=True)
reviews = merged_df[merged_df['_merge']=='left_only']

# traing set = reviews
# test set = last_watched_df

# %%
# Get unique user_id and film
user_film = reviews[['user_id','film']].drop_duplicates()

# Get the unique films and unique users
print('Unique users: ',len(user_film['user_id'].unique()))
print('Unique films: ',len(user_film['film'].unique()))
# Out:
# Unique users:  8491
# Unique films:  90418

# %%
# Check the film number per user
film_per_user = user_film.groupby('user_id')['film'].count().reset_index()
film_per_user = film_per_user.rename(columns={'film':'Count'})
print('The max number film per user:', film_per_user['Count'].max())
print('The min number film per user:', film_per_user['Count'].min())
print('The average number film per user:', film_per_user['Count'].mean())
print('The median number film per user:', film_per_user['Count'].median())
print('The 25 percent number film per user:', film_per_user['Count'].quantile(0.25))
print('The 75 percent number film per user:', film_per_user['Count'].quantile(0.75))
# Out:
# The max number film per user: 316
# The min number film per user: 2
# The average number film per user: 91.14968790484042
# The median number film per user: 114.0
# The 25 percent number film per user: 64.0
# The 75 percent number film per user: 118.0

# %%
# check the percentage
data = film_per_user['Count']
bins = [0, 10, 30, 50, 70,90,110,130,150,170,200]  
labels = ['0-10', '10-30','30-50', '50-70','70-90','90-110','110-130','130-150','150-170','170-200']  
data_binned = pd.cut(data, bins=bins, labels=labels)
data_binned = data_binned.value_counts().reset_index().rename(columns={'Count':'Bin'})
data_binned['percentage'] = data_binned['count']/data_binned['count'].sum()*100
data_binned
# Out:
#        Bin  count  percentage
# 0  110-130   4611   54.317352
# 1   90-110   1044   12.298268
# 2    30-50    698    8.222405
# 3    10-30    695    8.187066
# 4    50-70    592    6.973731
# 5    70-90    511    6.019555
# 6     0-10    309    3.640005
# 7  130-150     23    0.270939
# 8  150-170      6    0.070680
# 9  170-200      0    0.000000

# %%
# Check the user number per film
user_per_film = user_film.groupby('film')['user_id'].count().reset_index()
user_per_film = user_per_film.rename(columns={'user_id':'Count'})
print('The max number user per film:', user_per_film['Count'].max())
print('The min number user per film:', user_per_film['Count'].min())
print('The average number user per film:', user_per_film['Count'].mean())
print('The median number user per film:', user_per_film['Count'].median())
print('The 25 percent number user per film:', user_per_film['Count'].quantile(0.25))
print('The 75 percent number film per user:', user_per_film['Count'].quantile(0.75))
# Out:
# The max number user per film: 2384
# The min number user per film: 1
# The average number user per film: 8.559711561857153
# The median number user per film: 1.0
# The 25 percent number user per film: 1.0
# The 75 percent number film per user: 4.0

# %%
# check the percentage
data_film = user_per_film['Count']
bins = [0, 1, 3, 5, 10,20,50,100,200,500,1000,10000]  
labels = ['0-1', '1-3','3-5', '5-10','10-20','20-50','50-100','100-200','200-500','500-1000','1000-10000']  
data_film_binned = pd.cut(data_film, bins=bins, labels=labels)
data_film_binned = data_film_binned.value_counts().reset_index().rename(columns={'Count':'Bin'})
data_film_binned['percentage'] = data_film_binned['count']/data_film_binned['count'].sum()*100
data_film_binned
# Out:
#            Bin  count  percentage
# 0          0-1  45943   50.811785
# 1          1-3  20094   22.223451
# 2          3-5   6788    7.507355
# 3         5-10   6773    7.490765
# 4        10-20   4618    5.107390
# 5        20-50   3499    3.869805
# 6       50-100   1402    1.550576
# 7      100-200    794    0.878144
# 8      200-500    399    0.441284
# 9     500-1000     81    0.089584
# 10  1000-10000     27    0.029861

# %% [markdown]
# ## Filtering

# %% [markdown]
# 1. Filter users and film by isolation forest method

# %%
# define function
def insolationforest(df):
    # Use insolation Forest to test outliers
    contamination_levels = [0.1, 0.2, 0.3,0.4]
    best_contamination = None
    best_silhouette = -1  # Initialize with a low silhouette score

    for contamination in contamination_levels:
        model = IsolationForest(contamination=contamination)
        df['anomaly'] = model.fit_predict(df[['Count']])
        
        # Calculate the Silhouette Score
        if (df['anomaly'] == -1).sum() > 0:  # Ensure there are outliers
            score = silhouette_score(df[['Count']], df['anomaly'])
            print(f"Contamination: {contamination}, Silhouette Score: {score}")
            
            # Track the best contamination level
            if score > best_silhouette:
                best_silhouette = score
                best_contamination = contamination
    print(f"Best contamination level: {best_contamination} with Silhouette Score: {best_silhouette}")

# %%
# get the filtered dataframe
def filtered_df_IF(df,key,param):
    # Fit the model
    model = IsolationForest(contamination=param)  # Adjust contamination based on expected outlier ratio
    df['anomaly'] = model.fit_predict(df[['Count']])

    # Identify outliers
    outliers_film = df[df['anomaly'] == -1]
    outliers_film = outliers_film.reset_index()[[key,'Count']]
    outliers_film.sort_values(by='Count')

    # Filter outliters from film_per_user
    merged = df.merge(outliers_film, on=[key, 'Count'], how='left', indicator=True)
    filtered_df_IF = merged[merged['_merge'] == 'left_only'].drop(columns='_merge')
    return filtered_df_IF

# %%
# filter user
insolationforest(film_per_user)
# Out:
# Contamination: 0.1, Silhouette Score: 0.5419593996270637
# Contamination: 0.2, Silhouette Score: 0.46895582843318756
# Contamination: 0.3, Silhouette Score: 0.6125667390095253
# Contamination: 0.4, Silhouette Score: 0.67652317496699
# Best contamination level: 0.4 with Silhouette Score: 0.67652317496699

# %%
# filter film
insolationforest(user_per_film)
# Out:
# Contamination: 0.1, Silhouette Score: 0.8398832164867056
# Contamination: 0.2, Silhouette Score: 0.6910720047349558
# Contamination: 0.3, Silhouette Score: 0.5701559043050332
# Contamination: 0.4, Silhouette Score: 0.44985803534722807
# Best contamination level: 0.1 with Silhouette Score: 0.8398832164867056

# %%
# get the filtered user table
filtered_user_IF = filtered_df_IF(film_per_user,'user_id',0.4)

# get the filtered user table
filtered_film_IF = filtered_df_IF(user_per_film,'film',0.1)

# %% [markdown]
# 2. Filter user and film manually

# %%
# Filter the user and film below medium value
filtered_user_median=film_per_user[(film_per_user['Count']>=film_per_user['Count'].median())]
filtered_film_median=user_per_film[(user_per_film['Count']>=user_per_film['Count'].median())]

# Filter the user and film below MEAN value
filtered_user_mean=film_per_user[(film_per_user['Count']>=film_per_user['Count'].mean())]
filtered_film_mean=user_per_film[(user_per_film['Count']>=user_per_film['Count'].mean())]

# Filter the user and film between 0.25-0.75
user_25 = film_per_user['Count'].quantile(0.25)
user_75 = film_per_user['Count'].quantile(0.75)
film_25 = user_per_film['Count'].quantile(0.25)
film_75 = user_per_film['Count'].quantile(0.75)
filtered_user_quantile = film_per_user[(film_per_user['Count']>user_25)&(film_per_user['Count']<user_75)]
filtered_film_quantile = user_per_film[(user_per_film['Count']>film_25)&(user_per_film['Count']<film_75)]

# Filter the user and film predefined(65% of users)
filtered_user_65 = film_per_user[(film_per_user['Count']>=90)&(film_per_user['Count']<=130)]
filtered_film_50_100 = user_per_film[(user_per_film['Count']>=50)&(user_per_film['Count']<=100)]
filtered_film_50_200 = user_per_film[(user_per_film['Count']>=50)&(user_per_film['Count']<=200)]
filtered_film_100_500 = user_per_film[(user_per_film['Count']>=100)&(user_per_film['Count']<=500)]
filtered_film_100_1000 = user_per_film[(user_per_film['Count']>=100)&(user_per_film['Count']<=1000)]
filtered_film_200_1000 = user_per_film[(user_per_film['Count']>=200)&(user_per_film['Count']<=1000)]
filtered_film_200_500 = user_per_film[(user_per_film['Count']>=200)&(user_per_film['Count']<=500)]

# %% [markdown]
# ## Check sparsity

# %%
# Define a funtion to calcualte the matrix 
def filtered_user_film_matrix(filtered_user,filtered_film):

    # merge the final table user-film-rating
    final_filtered_df = filtered_user.merge(reviews,how='left',on='user_id').merge(filtered_film,how='inner',on='film')
    final_filtered_df=final_filtered_df[['user_id','film','rating']]
    final_filtered_df = final_filtered_df.drop_duplicates()

    # Initialize separate LabelEncoders for user_id and Film
    #user_encoder = LabelEncoder()
    #film_encoder = LabelEncoder()

    # Encode the 'user_id' column
    #final_filtered_df['user_id'] = user_encoder.fit_transform(final_filtered_df['user_id'])

    # Encode the 'Film' column
    #final_filtered_df['film'] = film_encoder.fit_transform(final_filtered_df['film'])

    # Create user-item matrix
    user_item_matrix = final_filtered_df.pivot_table(index='user_id', columns='film', values='rating', fill_value=0)

    # Calculate sparsity
    num_non_zero_entries = (user_item_matrix != 0).sum().sum()  # Count of non-zero entries
    total_entries = user_item_matrix.size  # Total entries in the matrix
    sparsity = 1 - (num_non_zero_entries / total_entries)  # Sparsity value
    sparsity_percentage = sparsity * 100  # Sparsity percentage

    print(f'Matix size:',user_item_matrix.shape)
    print(f"Sparsity: {sparsity:.4f}")
    print(f"Sparsity Percentage: {sparsity_percentage:.2f}%")
    return user_item_matrix

# %%
# Check sparsity
df_userIF_filmIF = filtered_user_film_matrix(filtered_user_IF,filtered_film_IF)
# Out:
# Matix size: (5112, 72218)
# Sparsity: 0.9996
# Sparsity Percentage: 99.96%

# %%
# Check sparsity
df_userMEDI_filmMEDI = filtered_user_film_matrix(filtered_user_median,filtered_film_median)
# Out:
# Matix size: (4276, 78204)
# Sparsity: 0.9986
# Sparsity Percentage: 99.86%

# %%
# Check sparsity
df_userAVG_filmAVG = filtered_user_film_matrix(filtered_user_mean,filtered_film_mean)
# Out:
# Matix size: (5659, 12702)
# Sparsity: 0.9934
# Sparsity Percentage: 99.34%

# %%
# Check sparsity
df_userPERCEN_filmPERCEN = filtered_user_film_matrix(filtered_user_quantile,filtered_film_quantile)
# Out:
# Matix size: (3086, 14032)
# Sparsity: 0.9996
# Sparsity Percentage: 99.96%

# %%
# Check sparsity
df_user65_film50_200 = filtered_user_film_matrix(filtered_user_65,filtered_film_50_200)
# Out:
# Matix size: (5662, 2254)
# Sparsity: 0.9870
# Sparsity Percentage: 98.70%

# %%
# Check sparsity
df_userIF_film50_200 = filtered_user_film_matrix(filtered_user_IF,filtered_film_50_200)
# Out:
# Matix size: (5128, 2254)
# Sparsity: 0.9869
# Sparsity Percentage: 98.69%

# %%
# Check sparsity
df_userIF_film50_100 = filtered_user_film_matrix(filtered_user_IF,filtered_film_50_100)
# Out:
# Matix size: (5116, 1460)
# Sparsity: 0.9902
# Sparsity Percentage: 99.02%

# %%
# Check sparsity
df_userIF_film100_500 = filtered_user_film_matrix(filtered_user_IF,filtered_film_100_500)
# Out:
# Matix size: (5122, 1213)
# Sparsity: 0.9742
# Sparsity Percentage: 97.42%

# %%
# Check sparsity
df_userIF_film100_1000 = filtered_user_film_matrix(filtered_user_IF,filtered_film_100_1000)
# Out:
# Matix size: (5123, 1294)
# Sparsity: 0.9703
# Sparsity Percentage: 97.03%

# %%
# Check sparsity
df_userIF_film200_1000 = filtered_user_film_matrix(filtered_user_IF,filtered_film_200_1000)
# Out:
# Matix size: (5094, 483)
# Sparsity: 0.9522
# Sparsity Percentage: 95.22%

# %%
# Check sparsity
df_user65_film200_1000 = filtered_user_film_matrix(filtered_user_65,filtered_film_200_1000)
# Out:
# Matix size: (5624, 483)
# Sparsity: 0.9523
# Sparsity Percentage: 95.23%

# %%
# Check sparsity
df_userIF_film200_500 = filtered_user_film_matrix(filtered_user_IF,filtered_film_200_500)
# Out:
# Matix size: (5074, 402)
# Sparsity: 0.9604
# Sparsity Percentage: 96.04%

# %% [markdown]
# We will choose df_user65_film200_1000 as basetable to go further analysis

# %%
# filtered table
def merge_table(filtered_user,filtered_film,reviews):
    # Merge the final table user-film-rating
    final_filtered_df = filtered_user.merge(reviews, how='left', on='user_id') \
                                        .merge(filtered_film, how='inner', on='film')
    final_filtered_df = final_filtered_df[['user_id', 'film', 'date','rating']].drop_duplicates()
    return final_filtered_df

# %%
# save the train set which is used to build the model
final_filtered_df = merge_table(filtered_user_65,filtered_film_200_1000,reviews)
final_filtered_df.to_csv('train_df.csv')

# %%
# save the test set which is used to evaluate the model
last_watched_df2 = final_filtered_df.merge(last_watched_df,how='left',on='user_id')[['user_id','film_y']].rename(columns={'film_y':'film'})
last_watched_df2 = last_watched_df2.groupby('user_id').agg({
        'film': lambda x: set(x)       
    }).reset_index().rename(columns = {'film':'true_items'})
last_watched_df2.to_csv('last_watched.csv')

# %% [markdown]
# ## SVD model

# %%
# user-based collaborative filtering by using SVD

# define the recommendation function 
def get_recommendations_SVD(final_filtered_df, user_ids, num_recommendations=5):
    """
    Generate top N recommendations for each user in user_ids using SVD.
    """

    # Load data into Surprise's Dataset format
    reader = Reader(rating_scale=(1, 5))
    data = Dataset.load_from_df(final_filtered_df[['user_id', 'film', 'rating']], reader)
    
    # Build the trainset and train the SVD model
    trainset = data.build_full_trainset()
    algo = SVD()
    algo.fit(trainset)

    # Initialize an empty list to store recommendations
    recommendations_list = []

    # Loop through each user and get recommendations
    for user_id in user_ids:
        try:
            # Get a list of all items
            all_items = trainset.all_items()
            all_item_ids = [trainset.to_raw_iid(item) for item in all_items]

            # Get items the user has already rated
            user_inner_id = trainset.to_inner_uid(user_id)
            user_rated_items = set([trainset.to_raw_iid(item[0]) for item in trainset.ur[user_inner_id]])

            # Filter out items the user has already rated
            items_to_predict = [item for item in all_item_ids if item not in user_rated_items]

            # Predict ratings for all items the user has not rated yet
            predictions = [algo.predict(user_id, item_id) for item_id in items_to_predict]

            # Sort predictions by estimated rating and get the top N
            predictions.sort(key=lambda x: x.est, reverse=True)
            top_n_recommendations = predictions[:num_recommendations]

            # Append each recommendation to the list as a tuple (user_id, film, predicted_rating)
            for pred in top_n_recommendations:
                recommendations_list.append((user_id, pred.iid, pred.est))
        
        except ValueError:
            # Skip users that aren't in the training set without printing a message
            continue
    # Convert the list of recommendations to a DataFrame
    recommendations_df = pd.DataFrame(recommendations_list, columns=['user_id', 'film', 'predicted_rating'])

    return recommendations_df

# %%
# Assuming you have lists of filtered users and films and a list of user IDs    
user_ids = final_filtered_df['user_id'].unique()  # Get unique user IDs from your data
pred_list = get_recommendations_SVD(final_filtered_df, user_ids, num_recommendations=5)    # -- > no split dataset can work fast

# Convert the list of recommendations to a DataFrame
svd_df = pd.DataFrame(pred_list)

# transform the table
prediction_svd_df = svd_df.groupby('user_id').agg({
    'film': lambda x: set(x)}).reset_index().rename(columns={'film':'predicted_items'})

# %%
# Final table
# merge recommended table and last watched table
svd_recommended_df = prediction_svd_df.merge(last_watched_df2, how='left',on='user_id')

# %% [markdown]
# ## Similarity Model

# %%
# calculate the similarity
user_similarity = cosine_similarity(df_user65_film200_1000.fillna(0))
user_similarity_df = pd.DataFrame(user_similarity, index=df_user65_film200_1000.index, columns=df_user65_film200_1000.index)

# %%
# Function to predict ratings for a single user
def predict_ratings(user_id, df, user_similarity_df, top_k=2):
    # Get similar users for the target user
    similar_users = user_similarity_df[user_id].sort_values(ascending=False).iloc[1:top_k+1]
    # Weighted average of similar users' ratings
    predicted_ratings = (similar_users.values[:, None] * df.loc[similar_users.index]).sum(axis=0) / similar_users.sum()
    return predicted_ratings

# Predict ratings for all users
def predict_all_users(df, user_similarity_df, top_k=2):
    predicted_ratings_all = {}
    for user_id in df.index:
        predicted_ratings_all[user_id] = predict_ratings(user_id, df, user_similarity_df, top_k)
    # Convert predictions into a DataFrame
    return pd.DataFrame(predicted_ratings_all).T

# Predict ratings for all users
predicted_ratings_df = predict_all_users(df_user65_film200_1000, user_similarity_df)

# %%
# extract top k recommended items
def get_top_k(predicted_df, k=5):
    return predicted_df.apply(lambda x: x.nlargest(k).index, axis=1)

top_k_recommendations = get_top_k(predicted_ratings_df, k=5)

# Transform data
def transform_data(data):
    # Convert each user's films into a set
    transformed_data = [{'user_id': user_id, 'film': set(films)} for user_id, films in data.items()]
    # Convert into a DataFrame
    return pd.DataFrame(transformed_data)

# Apply transformation
transformed_df = transform_data(top_k_recommendations)

# get the final table as data frame
similarity_df = transformed_df.reset_index().drop(columns=['index'])

# %%
# merge recommended table and last watched table
similarity_recommended_df = similarity_df.merge(last_watched_df2, how='left',on='user_id').rename(columns={'film':'predicted_items'})

# %% [markdown]
# ## Matrix Factorization Model

# %%
# matrix factorization function
def matrix_factorization(final_filtered_df, num_factors=10, num_iterations=100, learning_rate=0.01, reg_param=0.02):
    """
    Perform matrix factorization using gradient descent.

    Parameters:
        final_filtered_df (pd.DataFrame): DataFrame with columns ['user_id', 'film', 'rating'].
        num_factors (int): Number of latent factors.
        num_iterations (int): Number of iterations for gradient descent.
        learning_rate (float): Learning rate for gradient updates.
        reg_param (float): Regularization parameter.

    Returns:
        dict: User latent factors (P) and Item latent factors (Q).
        pd.DataFrame: Predicted ratings DataFrame.
    """
    # Create a mapping for user and film IDs to matrix indices
    user_mapping = {user: idx for idx, user in enumerate(final_filtered_df['user_id'].unique())}
    film_mapping = {film: idx for idx, film in enumerate(final_filtered_df['film'].unique())}
    reverse_film_mapping = {idx: film for film, idx in film_mapping.items()}

    # Get the number of users and items
    num_users = len(user_mapping)
    num_items = len(film_mapping)

    # Initialize user and item latent factor matrices (random values)
    P = np.random.normal(scale=1.0 / num_factors, size=(num_users, num_factors))
    Q = np.random.normal(scale=1.0 / num_factors, size=(num_items, num_factors))

    # Create a ratings matrix
    R = np.zeros((num_users, num_items))
    for _, row in final_filtered_df.iterrows():
        R[user_mapping[row['user_id']], film_mapping[row['film']]] = row['rating']

    # Perform gradient descent
    for iteration in range(num_iterations):
        for u in range(num_users):
            for i in range(num_items):
                if R[u, i] > 0:  # Only update for non-zero ratings
                    # Compute the error for the prediction
                    error = R[u, i] - np.dot(P[u, :], Q[i, :])
                    
                    # Update user and item latent factors
                    P[u, :] += learning_rate * (error * Q[i, :] - reg_param * P[u, :])
                    Q[i, :] += learning_rate * (error * P[u, :] - reg_param * Q[i, :])
        
        # Compute total loss (optional, for monitoring)
        total_loss = 0
        for u in range(num_users):
            for i in range(num_items):
                if R[u, i] > 0:
                    total_loss += (R[u, i] - np.dot(P[u, :], Q[i, :])) ** 2
                    total_loss += reg_param * (np.linalg.norm(P[u, :]) ** 2 + np.linalg.norm(Q[i, :]) ** 2)
        print(f"Iteration {iteration + 1}/{num_iterations}, Loss: {total_loss:.4f}")

    # Predict ratings for all user-item pairs
    predicted_ratings = np.dot(P, Q.T)

    # Convert predictions back to a DataFrame
    recommendations = []
    for user_id, user_idx in user_mapping.items():
        for item_idx, predicted_rating in enumerate(predicted_ratings[user_idx]):
            film_id = reverse_film_mapping[item_idx]
            recommendations.append((user_id, film_id, predicted_rating))

    recommendations_df = pd.DataFrame(recommendations, columns=['user_id', 'film', 'predicted_rating'])

    return {'P': P, 'Q': Q}, recommendations_df

# %%
# train model
latent_factors, matrix_factorized_pred= matrix_factorization(final_filtered_df, num_factors=10, num_iterations=100, learning_rate=0.01, reg_param=0.02)
# Out:
# Iteration 1/100, Loss: 1334812.2122
# Iteration 2/100, Loss: 158638.5386
# Iteration 3/100, Loss: 113377.1348
# Iteration 4/100, Loss: 107795.9137
# Iteration 5/100, Loss: 104932.0882
# Iteration 6/100, Loss: 102695.9267
# Iteration 7/100, Loss: 100686.2910
# Iteration 8/100, Loss: 98766.8722
# Iteration 9/100, Loss: 96880.9683
# Iteration 10/100, Loss: 95006.4936
# Iteration 11/100, Loss: 93140.9287
# Iteration 12/100, Loss: 91294.1729
# Iteration 13/100, Loss: 89483.4530
# Iteration 14/100, Loss: 87728.7321
# Iteration 15/100, Loss: 86048.6996
# Iteration 16/100, Loss: 84457.9539
# Iteration 17/100, Loss: 82965.7427
# Iteration 18/100, Loss: 81576.0628
# Iteration 19/100, Loss: 80288.5716
# Iteration 20/100, Loss: 79099.7723
# Iteration 21/100, Loss: 78004.1400
# Iteration 22/100, Loss: 76995.0429
# Iteration 23/100, Loss: 76065.4231
# Iteration 24/100, Loss: 75208.2601
# Iteration 25/100, Loss: 74416.8547
# Iteration 26/100, Loss: 73684.9835
# Iteration 27/100, Loss: 73006.9639
# Iteration 28/100, Loss: 72377.6637
# Iteration 29/100, Loss: 71792.4789
# Iteration 30/100, Loss: 71247.2952
# Iteration 31/100, Loss: 70738.4426
# Iteration 32/100, Loss: 70262.6492
# Iteration 33/100, Loss: 69816.9972
# Iteration 34/100, Loss: 69398.8814
# Iteration 35/100, Loss: 69005.9729
# Iteration 36/100, Loss: 68636.1861
# Iteration 37/100, Loss: 68287.6495
# Iteration 38/100, Loss: 67958.6805
# Iteration 39/100, Loss: 67647.7637
# Iteration 40/100, Loss: 67353.5306
# Iteration 41/100, Loss: 67074.7437
# Iteration 42/100, Loss: 66810.2814
# Iteration 43/100, Loss: 66559.1253
# Iteration 44/100, Loss: 66320.3487
# Iteration 45/100, Loss: 66093.1072
# Iteration 46/100, Loss: 65876.6297
# Iteration 47/100, Loss: 65670.2110
# Iteration 48/100, Loss: 65473.2049
# Iteration 49/100, Loss: 65285.0183
# Iteration 50/100, Loss: 65105.1060
# Iteration 51/100, Loss: 64932.9662
# Iteration 52/100, Loss: 64768.1359
# Iteration 53/100, Loss: 64610.1875
# Iteration 54/100, Loss: 64458.7255
# Iteration 55/100, Loss: 64313.3836
# Iteration 56/100, Loss: 64173.8219
# Iteration 57/100, Loss: 64039.7245
# Iteration 58/100, Loss: 63910.7980
# Iteration 59/100, Loss: 63786.7685
# Iteration 60/100, Loss: 63667.3812
# Iteration 61/100, Loss: 63552.3977
# Iteration 62/100, Loss: 63441.5956
# Iteration 63/100, Loss: 63334.7663
# Iteration 64/100, Loss: 63231.7148
# Iteration 65/100, Loss: 63132.2580
# Iteration 66/100, Loss: 63036.2241
# Iteration 67/100, Loss: 62943.4517
# Iteration 68/100, Loss: 62853.7890
# Iteration 69/100, Loss: 62767.0930
# Iteration 70/100, Loss: 62683.2291
# Iteration 71/100, Loss: 62602.0704
# Iteration 72/100, Loss: 62523.4970
# Iteration 73/100, Loss: 62447.3958
# Iteration 74/100, Loss: 62373.6598
# Iteration 75/100, Loss: 62302.1880
# Iteration 76/100, Loss: 62232.8845
# Iteration 77/100, Loss: 62165.6587
# Iteration 78/100, Loss: 62100.4247
# Iteration 79/100, Loss: 62037.1009
# Iteration 80/100, Loss: 61975.6100
# Iteration 81/100, Loss: 61915.8785
# Iteration 82/100, Loss: 61857.8366
# Iteration 83/100, Loss: 61801.4179
# Iteration 84/100, Loss: 61746.5594
# Iteration 85/100, Loss: 61693.2010
# Iteration 86/100, Loss: 61641.2854
# Iteration 87/100, Loss: 61590.7581
# Iteration 88/100, Loss: 61541.5671
# Iteration 89/100, Loss: 61493.6629
# Iteration 90/100, Loss: 61446.9982
# Iteration 91/100, Loss: 61401.5278
# Iteration 92/100, Loss: 61357.2087
# Iteration 93/100, Loss: 61313.9995
# Iteration 94/100, Loss: 61271.8609
# Iteration 95/100, Loss: 61230.7552
# Iteration 96/100, Loss: 61190.6464
# Iteration 97/100, Loss: 61151.5000
# Iteration 98/100, Loss: 61113.2830
# Iteration 99/100, Loss: 61075.9637
# Iteration 100/100, Loss: 61039.5118

# %%
# transform the table
prediction_MF_df = matrix_factorized_pred.groupby('user_id').agg({'film': lambda x: set(x)}).reset_index().rename(columns={'film':'predicted_items'})

# Final table
# merge recommended table and last watched table
MF_recommended_df = prediction_MF_df.merge(last_watched_df2, how='left',on='user_id')

# %% [markdown]
# ## Clustering Model

# %%
# clustering function
def clustering_recommendations(final_filtered_df, num_clusters=5, top_n=5):
    """
    Generate recommendations using clustering-based methods.

    Parameters:
        final_filtered_df (pd.DataFrame): DataFrame with columns ['user_id', 'film', 'rating'].
        num_clusters (int): Number of clusters for K-Means.
        top_n (int): Number of recommendations per user.

    Returns:
        pd.DataFrame: DataFrame with recommendations for each user.
    """
    # Create a user-item interaction matrix
    interaction_matrix = final_filtered_df.pivot_table(
        index='user_id', columns='film', values='rating', fill_value=0
    )

    # Perform K-Means clustering on users
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    user_clusters = kmeans.fit_predict(interaction_matrix)

    # Add cluster information to the DataFrame
    interaction_matrix['cluster'] = user_clusters
    cluster_centroids = pd.DataFrame(kmeans.cluster_centers_, columns=interaction_matrix.columns[:-1])

    # Generate recommendations for each user
    recommendations = []
    for user_id, row in interaction_matrix.iterrows():
        user_cluster = row['cluster']
        user_ratings = row.drop('cluster')

        # Find the cluster centroid and suggest top items not rated by the user
        cluster_mean = cluster_centroids.loc[user_cluster]
        unrated_items = user_ratings[user_ratings == 0].index
        recommended_items = cluster_mean[unrated_items].sort_values(ascending=False).head(top_n)

        for film, score in recommended_items.items():
            recommendations.append((user_id, film, score))

    # Convert recommendations to a DataFrame
    recommendations_df = pd.DataFrame(recommendations, columns=['user_id', 'film', 'predicted_rating'])

    return recommendations_df

# %%
# run the funciton
clustering_pred = clustering_recommendations(final_filtered_df, num_clusters=5, top_n=5)

# %%
# transform the table
prediction_Clustering_df = clustering_pred.groupby('user_id').agg({'film': lambda x: set(x)}).reset_index().rename(columns={'film':'predicted_items'})

# Final table
# merge recommended table and last watched table
Clustering_recommended_df = prediction_Clustering_df.merge(last_watched_df2, how='left',on='user_id')

# %% [markdown]
# ## Association Rule

# %%
def association_rule_recommendations_fpgrowth(final_filtered_df, min_support=0.05, min_confidence=0.6, top_n=5):
    """
    Generate recommendations using FP-Growth for frequent itemset mining.
    """
    interaction_matrix = final_filtered_df.pivot_table(
        index='user_id', columns='film', values='rating', aggfunc='count', fill_value=0
    ).applymap(lambda x: 1 if x > 0 else 0)

    frequent_itemsets = fpgrowth(interaction_matrix, min_support=min_support, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence,num_itemsets=10)

    print(f"Number of rules generated: {len(rules)}")

    recommendations = []
    for user_id, row in interaction_matrix.iterrows():
        user_items = set(row[row == 1].index)
        applicable_rules = rules[rules['antecedents'].apply(lambda x: x.issubset(user_items))]

        print(f"User {user_id} - {len(applicable_rules)} applicable rules found")

        for _, rule in applicable_rules.nlargest(top_n, 'confidence').iterrows():
            for item in rule['consequents']:
                if item not in user_items:
                    recommendations.append((user_id, item, rule['confidence']))

    return pd.DataFrame(recommendations, columns=['user_id', 'film', 'confidence'])

# %%
# apply
AR_pred = association_rule_recommendations_fpgrowth(final_filtered_df, min_support=0.03, min_confidence=0.5, top_n=5)
# Out:
# C:\Users\dlish\AppData\Local\Temp\ipykernel_12252\121887269.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   interaction_matrix = final_filtered_df.pivot_table(
# c:\Users\dlish\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Number of rules generated: 35
# User 00skywalkerr - 9 applicable rules found
# User 0dsanyu - 1 applicable rules found
# User 0nly0ne0f - 0 applicable rules found
# User 0nn109 - 2 applicable rules found
# User 10aflyviper - 2 applicable rules found
# User 10romeo - 0 applicable rules found
# User 11us - 14 applicable rules found
# User 13visions - 6 applicable rules found
# User 15digitusername - 4 applicable rules found
# User 1_lick_walls - 0 applicable rules found
# User 1carly - 1 applicable rules found
# User 1so - 0 applicable rules found
# User 1zzythe_strange - 0 applicable rules found
# User 2bladesbalin - 0 applicable rules found
# User 2ndrules - 1 applicable rules found
# User 2old2dieyoung - 0 applicable rules found
# User 2spiderheads - 2 applicable rules found
# User 360smash - 0 applicable rules found
# User 3a_kd - 1 applicable rules found
# User 3goldballs - 1 applicable rules found
# User 3lillen - 2 applicable rules found
# User 46tomatoes - 1 applicable rules found
# User 47ronin100 - 4 applicable rules found
# User 4gv - 1 applicable rules found
# User 4ivilo - 2 applicable rules found
# User 4kcomrade - 0 applicable rules found
# User 4kkollecter - 4 applicable rules found
# User 4nissa - 1 applicable rules found
# User 4nning - 1 applicable rules found
# User 505pike - 2 applicable rules found
# User 5amuel - 0 applicable rules found
# User 69angrymen - 0 applicable rules found
# User 6sheets - 2 applicable rules found
# User 7038634357 - 1 applicable rules found
# User 7morgvnstrn0s - 0 applicable rules found
# User 7nickthompson - 5 applicable rules found
# User 7omomb - 1 applicable rules found
# User 8256matcha - 1 applicable rules found
# User 8hannaah - 0 applicable rules found
# User 90soph - 0 applicable rules found
# User 9413 - 0 applicable rules found
# User 953byblackmidi - 0 applicable rules found
# User 96vrdn - 1 applicable rules found
# User 97fen - 0 applicable rules found
# User __0_0____ - 0 applicable rules found
# User __tjh__ - 0 applicable rules found
# User _adelaide - 0 applicable rules found
# User _ahld_ - 0 applicable rules found
# User _andrew_cnb_ - 0 applicable rules found
# User _arthur2005 - 4 applicable rules found
# User _ash5 - 0 applicable rules found
# User _av_ - 0 applicable rules found
# User _becky_ - 1 applicable rules found
# User _dea_ - 0 applicable rules found
# User _drjackmovies_ - 0 applicable rules found
# User _eduard_ - 4 applicable rules found
# User _falsemirror - 6 applicable rules found
# User _famke - 0 applicable rules found
# User _fran_ - 0 applicable rules found
# User _fu - 2 applicable rules found
# User _indi111 - 2 applicable rules found
# User _jagodynski - 0 applicable rules found
# User _jay_ - 1 applicable rules found
# User _lucho_ - 2 applicable rules found
# User _michaelgill - 0 applicable rules found
# User _mrblakney - 1 applicable rules found
# User _natashha - 0 applicable rules found
# User _parker - 1 applicable rules found
# User _priti - 0 applicable rules found
# User _ratsnest - 1 applicable rules found
# User _rowenoake - 3 applicable rules found
# User _stevoreviews_ - 5 applicable rules found
# User _titan5 - 1 applicable rules found
# User _triviaeuphoria - 3 applicable rules found
# User _zemonreviews - 0 applicable rules found
# User a1y - 0 applicable rules found
# User a90z - 0 applicable rules found
# User a_hit - 0 applicable rules found
# User a_poetiso - 0 applicable rules found
# User aa56 - 0 applicable rules found
# User aaaaand_strops - 1 applicable rules found
# User aaditya95 - 0 applicable rules found
# User aardsy - 0 applicable rules found
# User aarongrady - 0 applicable rules found
# User aaronjolley01 - 0 applicable rules found
# User aaronjwatches - 11 applicable rules found
# User aaronswans - 4 applicable rules found
# User abbeyzeroultra - 0 applicable rules found
# User abbymreeves - 0 applicable rules found
# User abbynaugler - 17 applicable rules found
# User abdegilmopstuv - 14 applicable rules found
# User abelgance - 2 applicable rules found
# User abendo - 0 applicable rules found
# User abie_bowers - 3 applicable rules found
# User abigracec - 2 applicable rules found
# User abils13 - 2 applicable rules found
# User abinujp - 1 applicable rules found
# User aboemad - 2 applicable rules found
# User abreel - 0 applicable rules found
# User abysmios - 0 applicable rules found
# User acebonanza - 3 applicable rules found
# User acegracious - 3 applicable rules found
# User acetylsaliciliq - 0 applicable rules found
# User achaoticmess - 0 applicable rules found
# User acorna14 - 2 applicable rules found
# User acorns13 - 0 applicable rules found
# User acoutoumanos - 0 applicable rules found
# User adaezeio - 5 applicable rules found
# User adam27xz - 2 applicable rules found
# User adamh89 - 1 applicable rules found
# User adammichael78 - 0 applicable rules found
# User adamomega - 1 applicable rules found
# User adams2017 - 2 applicable rules found
# User adamsawafilm - 0 applicable rules found
# User adamsgoldberg - 1 applicable rules found
# User adaptor - 1 applicable rules found
# User adarah - 0 applicable rules found
# User adaydreaming - 1 applicable rules found
# User addisonben - 2 applicable rules found
# User adibou04 - 5 applicable rules found
# User adin - 1 applicable rules found
# User adirtzur - 2 applicable rules found
# User aditya960 - 1 applicable rules found
# User admiringcinema - 1 applicable rules found
# User adri79 - 0 applicable rules found
# User adrianabbott - 3 applicable rules found
# User adrianocamacho - 2 applicable rules found
# User adrianonm10 - 0 applicable rules found
# User adrianpinas - 0 applicable rules found
# User adryonvreo - 1 applicable rules found
# User advaithps - 0 applicable rules found
# User adzkasraczka - 0 applicable rules found
# User aechevarria - 1 applicable rules found
# User aelex88 - 0 applicable rules found
# User aelix - 0 applicable rules found
# User aestheticrat94 - 6 applicable rules found
# User afields9 - 0 applicable rules found
# User afroelfe - 0 applicable rules found
# User aft3rh0urs - 0 applicable rules found
# User ageminiwhore - 0 applicable rules found
# User agentconfucius - 0 applicable rules found
# User agentxcoop - 2 applicable rules found
# User aguscuenca - 0 applicable rules found
# User aguss_20 - 0 applicable rules found
# User agw1971 - 0 applicable rules found
# User ahdmagic - 7 applicable rules found
# User ahhleecia - 3 applicable rules found
# User ahnt - 3 applicable rules found
# User ahyankazmi - 0 applicable rules found
# User aialb - 0 applicable rules found
# User aicanna - 1 applicable rules found
# User aidan_gannon - 7 applicable rules found
# User aidangry - 1 applicable rules found
# User aidanhedges666 - 1 applicable rules found
# User aidantails - 1 applicable rules found
# User ailinodalaigh - 0 applicable rules found
# User aimee_rcs - 1 applicable rules found
# User ajeagleson - 1 applicable rules found
# User ajm1500 - 4 applicable rules found
# User akatskin - 0 applicable rules found
# User akbarfdlh_ - 0 applicable rules found
# User akirafanatic - 0 applicable rules found
# User akirajoonho - 0 applicable rules found
# User akoaytao - 0 applicable rules found
# User aks1214 - 0 applicable rules found
# User aktiu - 0 applicable rules found
# User aku - 0 applicable rules found
# User akusupernova - 3 applicable rules found
# User al_nsar19 - 0 applicable rules found
# User alaa_o - 0 applicable rules found
# User aladd - 5 applicable rules found
# User alan0669 - 0 applicable rules found
# User alaneternl - 0 applicable rules found
# User alanmorgan - 0 applicable rules found
# User albertbirney - 0 applicable rules found
# User albertl - 9 applicable rules found
# User albertosaul - 14 applicable rules found
# User alch_bass - 0 applicable rules found
# User ald_rin - 2 applicable rules found
# User aldort - 2 applicable rules found
# User alec593 - 1 applicable rules found
# User alecchalmers - 0 applicable rules found
# User alecchillingwof - 16 applicable rules found
# User aleee23 - 4 applicable rules found
# User alejandracrzz - 0 applicable rules found
# User alejandrodiosa - 0 applicable rules found
# User alele - 0 applicable rules found
# User alereye16 - 0 applicable rules found
# User alessandroberna - 3 applicable rules found
# User alessiapasin - 0 applicable rules found
# User alessilas - 1 applicable rules found
# User alex43 - 3 applicable rules found
# User alex_flaherty22 - 2 applicable rules found
# User alex_m_andrade - 0 applicable rules found
# User alex_murphy - 0 applicable rules found
# User alexanderheff - 9 applicable rules found
# User alexandrefr - 0 applicable rules found
# User alexcanales - 1 applicable rules found
# User alexddd - 1 applicable rules found
# User alexfarkas13 - 2 applicable rules found
# User alexjenna - 0 applicable rules found
# User alexknechtl - 0 applicable rules found
# User alexmandigo - 1 applicable rules found
# User alexmoss - 1 applicable rules found
# User alexnowell - 1 applicable rules found
# User alexrobotzz_ - 0 applicable rules found
# User alexsanchez87 - 6 applicable rules found
# User alexteichman - 1 applicable rules found
# User alextromagnetic - 1 applicable rules found
# User alexvalentine96 - 0 applicable rules found
# User alexx_02 - 3 applicable rules found
# User alexxxsandra - 2 applicable rules found
# User alexz - 0 applicable rules found
# User alexzipperer - 3 applicable rules found
# User alf_strife - 17 applicable rules found
# User alfonsopullum - 16 applicable rules found
# User aliceliddle - 0 applicable rules found
# User alicelove - 2 applicable rules found
# User alicemomo - 0 applicable rules found
# User alienkeyes - 0 applicable rules found
# User aliib - 14 applicable rules found
# User aline99 - 13 applicable rules found
# User alitadam12 - 2 applicable rules found
# User allaturka - 0 applicable rules found
# User allegedbeef - 1 applicable rules found
# User alli_aye - 0 applicable rules found
# User allisoncm - 0 applicable rules found
# User allisonrae - 0 applicable rules found
# User allorza - 0 applicable rules found
# User allyycat - 2 applicable rules found
# User almohad4 - 1 applicable rules found
# User alolanroy - 0 applicable rules found
# User alolfer - 4 applicable rules found
# User aloneawakeaware - 0 applicable rules found
# User alonsodvt - 1 applicable rules found
# User alphakeel - 15 applicable rules found
# User alsispunk - 2 applicable rules found
# User alsoknownasjo - 2 applicable rules found
# User altank86 - 0 applicable rules found
# User altmir - 0 applicable rules found
# User altnaaaaa - 0 applicable rules found
# User alucard8791 - 0 applicable rules found
# User alvinxander - 3 applicable rules found
# User alxyssa - 14 applicable rules found
# User alygabz - 4 applicable rules found
# User alyssaheinecke - 2 applicable rules found
# User ama - 0 applicable rules found
# User amadeofr - 0 applicable rules found
# User amalosy - 1 applicable rules found
# User aman20 - 1 applicable rules found
# User amandaahull - 0 applicable rules found
# User amandacore - 0 applicable rules found
# User amandawatson - 0 applicable rules found
# User amasiojutel - 4 applicable rules found
# User ambh - 0 applicable rules found
# User ambivalent_hoax - 6 applicable rules found
# User amcnal - 1 applicable rules found
# User amepeche - 0 applicable rules found
# User amirelbesher - 1 applicable rules found
# User amiresque - 0 applicable rules found
# User amlalqiran - 0 applicable rules found
# User amm1040 - 2 applicable rules found
# User amourtosse - 2 applicable rules found
# User amp16 - 1 applicable rules found
# User amselini - 14 applicable rules found
# User amule - 1 applicable rules found
# User amyann - 0 applicable rules found
# User amybrads - 0 applicable rules found
# User amyclouds - 1 applicable rules found
# User amyd3po - 0 applicable rules found
# User amyhensarling - 6 applicable rules found
# User amyhswan - 0 applicable rules found
# User amyslithium - 0 applicable rules found
# User amyster99 - 0 applicable rules found
# User amyyyyyyyy - 0 applicable rules found
# User amzesnaps - 8 applicable rules found
# User anabiel - 1 applicable rules found
# User anamaana - 0 applicable rules found
# User anamacnamara - 0 applicable rules found
# User anapaulaninap - 0 applicable rules found
# User anastasiazlatan - 0 applicable rules found
# User anatrnd - 0 applicable rules found
# User andreareyes - 0 applicable rules found
# User andreezy21 - 2 applicable rules found
# User andremario33 - 0 applicable rules found
# User andrew_debough - 1 applicable rules found
# User andrewbehm - 0 applicable rules found
# User andrewbrimstone - 3 applicable rules found
# User andrewc77 - 2 applicable rules found
# User andrewcurry30 - 0 applicable rules found
# User andrewelmore - 2 applicable rules found
# User andrewfernie - 3 applicable rules found
# User andrewgrainger1 - 1 applicable rules found
# User andrewhabashy - 0 applicable rules found
# User andrewmayererer - 0 applicable rules found
# User andrewsarchus - 18 applicable rules found
# User andrez15 - 0 applicable rules found
# User andriswah - 4 applicable rules found
# User andronicus3 - 0 applicable rules found
# User andthenwedanced - 0 applicable rules found
# User andy113 - 16 applicable rules found
# User andybaughman - 6 applicable rules found
# User andyh84 - 0 applicable rules found
# User andyjretro - 10 applicable rules found
# User andyloveopossum - 2 applicable rules found
# User andyyz - 0 applicable rules found
# User aneclecticmess - 13 applicable rules found
# User angeldgb - 0 applicable rules found
# User angelmilk - 1 applicable rules found
# User angelseuss - 1 applicable rules found
# User angyforg - 2 applicable rules found
# User anikulapo70 - 5 applicable rules found
# User animation_eater - 0 applicable rules found
# User animationolgist - 2 applicable rules found
# User anireip21 - 0 applicable rules found
# User anna1ucia - 0 applicable rules found
# User annahill - 1 applicable rules found
# User annalovezmovies - 0 applicable rules found
# User annalucialasky - 9 applicable rules found
# User annasecretpoet - 6 applicable rules found
# User annasophie - 1 applicable rules found
# User anneg1 - 2 applicable rules found
# User anniella - 0 applicable rules found
# User anniezzet - 5 applicable rules found
# User annxou - 1 applicable rules found
# User anomaly_sa - 2 applicable rules found
# User another_other - 2 applicable rules found
# User antbit - 1 applicable rules found
# User anteater97 - 0 applicable rules found
# User antfairall - 11 applicable rules found
# User anthonystarkey - 9 applicable rules found
# User antifurniture - 0 applicable rules found
# User antisocialboy - 0 applicable rules found
# User antnield - 0 applicable rules found
# User antoinela - 0 applicable rules found
# User anton_do - 2 applicable rules found
# User antonioacosta - 0 applicable rules found
# User antoniopatljak - 0 applicable rules found
# User antoniortegamar - 1 applicable rules found
# User antonwalbrook - 0 applicable rules found
# User antrace_ - 0 applicable rules found
# User aotero8 - 15 applicable rules found
# User apertureofdoom - 0 applicable rules found
# User apocalypsegoat - 0 applicable rules found
# User app1escruff - 0 applicable rules found
# User applewillows - 2 applicable rules found
# User apracticalman - 5 applicable rules found
# User aprandolph - 0 applicable rules found
# User aquasiox - 0 applicable rules found
# User aqueousermine - 1 applicable rules found
# User araarakubrick - 0 applicable rules found
# User arachnopyro - 1 applicable rules found
# User aramzs - 0 applicable rules found
# User arbogast23 - 5 applicable rules found
# User arbuckledreen - 0 applicable rules found
# User archiemabbutt - 16 applicable rules found
# User archlitzy - 1 applicable rules found
# User ardakuzyaka - 2 applicable rules found
# User arebec4 - 2 applicable rules found
# User areyoujoebanks - 4 applicable rules found
# User arftrooper9 - 4 applicable rules found
# User ari_kech - 1 applicable rules found
# User ariah77 - 1 applicable rules found
# User arianamarcial - 0 applicable rules found
# User arianammayy - 1 applicable rules found
# User ariqjaun - 2 applicable rules found
# User arjogupto - 0 applicable rules found
# User arkadipop - 11 applicable rules found
# User arkhamvideoclub - 0 applicable rules found
# User arkivsea - 0 applicable rules found
# User arlocnnr - 2 applicable rules found
# User arnarok - 2 applicable rules found
# User arnlott - 0 applicable rules found
# User arnoldist - 1 applicable rules found
# User arnotte - 0 applicable rules found
# User arranreviews - 1 applicable rules found
# User artfig42 - 0 applicable rules found
# User arthurpog - 10 applicable rules found
# User arthurtayl0r - 10 applicable rules found
# User arthurtzu - 3 applicable rules found
# User artthurfleckk - 1 applicable rules found
# User arttiel - 0 applicable rules found
# User arty_x - 1 applicable rules found
# User arushibhaskar - 0 applicable rules found
# User arvinclone - 3 applicable rules found
# User aryaakaya - 1 applicable rules found
# User asabovesotello - 5 applicable rules found
# User asadmapari - 5 applicable rules found
# User asaplilo - 0 applicable rules found
# User ascalaphid - 0 applicable rules found
# User ascella - 1 applicable rules found
# User asdfbatman - 0 applicable rules found
# User ash13mac - 0 applicable rules found
# User ashcrow - 1 applicable rules found
# User ashernielsen_13 - 17 applicable rules found
# User ashilou - 0 applicable rules found
# User ashiq_sulaiman - 0 applicable rules found
# User ashketchuplol - 2 applicable rules found
# User ashleya17 - 4 applicable rules found
# User ashleylynch - 0 applicable rules found
# User ashlynelaina - 6 applicable rules found
# User ashuston - 0 applicable rules found
# User ashymcr - 0 applicable rules found
# User asianamerica - 0 applicable rules found
# User asriram - 1 applicable rules found
# User astegner - 1 applicable rules found
# User astha_dedakiya - 0 applicable rules found
# User astratton1027 - 4 applicable rules found
# User astreeeeee - 0 applicable rules found
# User athenasreview - 0 applicable rules found
# User atombishup - 3 applicable rules found
# User atraumstadt - 0 applicable rules found
# User attamarkl - 0 applicable rules found
# User atul95 - 0 applicable rules found
# User audrakooney - 1 applicable rules found
# User auntfran - 0 applicable rules found
# User auroramacula - 0 applicable rules found
# User auspoy - 0 applicable rules found
# User austin_lawrence - 11 applicable rules found
# User austinh - 3 applicable rules found
# User austinmorgan - 3 applicable rules found
# User autolykiss - 3 applicable rules found
# User autophagy - 0 applicable rules found
# User autumn712 - 20 applicable rules found
# User autumnmischief - 0 applicable rules found
# User auzar - 0 applicable rules found
# User avacalva - 14 applicable rules found
# User aveday - 0 applicable rules found
# User aveer - 0 applicable rules found
# User averygiroux - 2 applicable rules found
# User averyydean - 3 applicable rules found
# User avidmoviefan7 - 3 applicable rules found
# User awat_asaad - 1 applicable rules found
# User awkautzer - 2 applicable rules found
# User axelino - 0 applicable rules found
# User axolotlmus - 4 applicable rules found
# User ayambakar - 0 applicable rules found
# User ayanamirei - 0 applicable rules found
# User aylumeetsmovies - 1 applicable rules found
# User aymesk - 0 applicable rules found
# User ayolah - 0 applicable rules found
# User ayrty - 0 applicable rules found
# User aytacsrkya - 0 applicable rules found
# User ayurii - 0 applicable rules found
# User azguiaro - 1 applicable rules found
# User aziraphale - 0 applicable rules found
# User b10tr0d - 0 applicable rules found
# User b4thepinksunset - 1 applicable rules found
# User b_jmk - 0 applicable rules found
# User b_noire - 0 applicable rules found
# User baadasssscinema - 1 applicable rules found
# User babebalbilbul - 2 applicable rules found
# User babygoo - 1 applicable rules found
# User babyroman - 0 applicable rules found
# User backwards_man - 0 applicable rules found
# User badabada - 0 applicable rules found
# User badbenson - 0 applicable rules found
# User badbitch17 - 0 applicable rules found
# User baddingtonbitch - 0 applicable rules found
# User badideasophia - 1 applicable rules found
# User bagadoomtibs - 3 applicable rules found
# User bagration - 14 applicable rules found
# User bailablefiend86 - 3 applicable rules found
# User baileewalsh - 0 applicable rules found
# User bailey96 - 2 applicable rules found
# User baileyzisa147 - 0 applicable rules found
# User bailster01 - 0 applicable rules found
# User bainvicky - 6 applicable rules found
# User bakerchum - 0 applicable rules found
# User bakir17 - 0 applicable rules found
# User balthazar2000 - 0 applicable rules found
# User bamdadadl - 0 applicable rules found
# User bamlett - 2 applicable rules found
# User bamsenalex - 0 applicable rules found
# User bandsaboutmovie - 0 applicable rules found
# User banjoks - 0 applicable rules found
# User bansheebeat - 9 applicable rules found
# User bantcher - 1 applicable rules found
# User banye - 5 applicable rules found
# User barbaracanaves - 0 applicable rules found
# User barbaraloden - 0 applicable rules found
# User barbarayaga - 8 applicable rules found
# User barbrajoan - 0 applicable rules found
# User bardex - 2 applicable rules found
# User barelyregal - 2 applicable rules found
# User barimeeee - 0 applicable rules found
# User barlasadema - 0 applicable rules found
# User barleystar - 3 applicable rules found
# User barleythedog - 0 applicable rules found
# User baronronan - 0 applicable rules found
# User barrettlilly - 0 applicable rules found
# User barry_convex - 4 applicable rules found
# User barryfreed - 0 applicable rules found
# User bartu99 - 0 applicable rules found
# User bashfoal - 1 applicable rules found
# User bastacheggy - 10 applicable rules found
# User basxita - 0 applicable rules found
# User bat0 - 2 applicable rules found
# User baticulo - 14 applicable rules found
# User batma8e - 2 applicable rules found
# User bauhaus - 0 applicable rules found
# User bawwsadface - 0 applicable rules found
# User baxsplosion - 3 applicable rules found
# User baystreetvideo - 0 applicable rules found
# User baz65 - 0 applicable rules found
# User bazinfan - 1 applicable rules found
# User bb13131313 - 0 applicable rules found
# User bbalas - 0 applicable rules found
# User bbell - 12 applicable rules found
# User bbergman11 - 0 applicable rules found
# User bbwithanxiety - 0 applicable rules found
# User bbyangel_alexis - 1 applicable rules found
# User bc007 - 0 applicable rules found
# User bc555 - 0 applicable rules found
# User bcarey8215 - 2 applicable rules found
# User bd009 - 14 applicable rules found
# User be_average - 0 applicable rules found
# User beachwoodbaker - 10 applicable rules found
# User beagerolin - 0 applicable rules found
# User beamercineast - 1 applicable rules found
# User bearfromgrizzly - 0 applicable rules found
# User bearsig - 17 applicable rules found
# User beatles_simp - 0 applicable rules found
# User beatriceales - 1 applicable rules found
# User beatrycze - 0 applicable rules found
# User beautifulkiller - 0 applicable rules found
# User beber89 - 0 applicable rules found
# User becky88 - 0 applicable rules found
# User beckysmovies - 0 applicable rules found
# User bee_cantsleep - 0 applicable rules found
# User beebi - 5 applicable rules found
# User beeenzzzzzzz - 1 applicable rules found
# User beeetrice - 0 applicable rules found
# User beefone - 0 applicable rules found
# User beerbatteredcod - 0 applicable rules found
# User beeryand - 5 applicable rules found
# User beetlebxm - 0 applicable rules found
# User beffy36 - 2 applicable rules found
# User beggarsoshat - 0 applicable rules found
# User begge - 0 applicable rules found
# User behindthefridge - 0 applicable rules found
# User belalubrosi - 0 applicable rules found
# User bellacadore - 1 applicable rules found
# User beluj66 - 1 applicable rules found
# User ben_pimpler - 4 applicable rules found
# User benafflecked - 0 applicable rules found
# User benaiatavares - 0 applicable rules found
# User benedict11 - 1 applicable rules found
# User benelliot - 0 applicable rules found
# User benfroggo - 1 applicable rules found
# User benjaminstephen - 1 applicable rules found
# User benjamintikjoeb - 1 applicable rules found
# User benlefou - 0 applicable rules found
# User benliamc - 18 applicable rules found
# User bennnnn1809 - 0 applicable rules found
# User benpcruz - 0 applicable rules found
# User benrogeral - 14 applicable rules found
# User benround7 - 0 applicable rules found
# User benrrr - 0 applicable rules found
# User benschade - 4 applicable rules found
# User benskylerhill - 7 applicable rules found
# User bentclouds - 2 applicable rules found
# User bergeron - 0 applicable rules found
# User bergman864 - 5 applicable rules found
# User bertpastore - 0 applicable rules found
# User bethmarley22 - 0 applicable rules found
# User bethsimpson - 0 applicable rules found
# User bethwinchester - 0 applicable rules found
# User betsythebear - 4 applicable rules found
# User betterloxp - 7 applicable rules found
# User bettyblair - 1 applicable rules found
# User bfalcon11 - 10 applicable rules found
# User bhaveshjoshi - 0 applicable rules found
# User bhavishya_z_ - 0 applicable rules found
# User biagiodr - 2 applicable rules found
# User biancamattos - 4 applicable rules found
# User biaswift - 0 applicable rules found
# User bibievany - 0 applicable rules found
# User big_kaiju_z - 1 applicable rules found
# User bigchill66 - 0 applicable rules found
# User bigchunky - 0 applicable rules found
# User bigdaddycool81 - 0 applicable rules found
# User biggerthanma - 0 applicable rules found
# User biggest_steve - 0 applicable rules found
# User biggie_halps - 0 applicable rules found
# User biggielee69 - 0 applicable rules found
# User biggumsrex - 10 applicable rules found
# User bigjackclifford - 0 applicable rules found
# User bigkahuna8 - 2 applicable rules found
# User bigmassivebelly - 19 applicable rules found
# User bigplaymike007 - 4 applicable rules found
# User bigsalad87 - 0 applicable rules found
# User bilboballin - 0 applicable rules found
# User bilderrahmen - 0 applicable rules found
# User bill626 - 2 applicable rules found
# User billiam4 - 0 applicable rules found
# User billmurphy - 10 applicable rules found
# User billybobbell - 0 applicable rules found
# User billys - 0 applicable rules found
# User binaxxb - 1 applicable rules found
# User bingemojo - 2 applicable rules found
# User bingorelia - 0 applicable rules found
# User binro - 1 applicable rules found
# User bio_humlebacken - 10 applicable rules found
# User bionicjaden - 0 applicable rules found
# User bipmate - 1 applicable rules found
# User birdman42 - 24 applicable rules found
# User bixieb - 0 applicable rules found
# User bjl1313 - 1 applicable rules found
# User bjv219 - 5 applicable rules found
# User bkgenreguy - 1 applicable rules found
# User blackdiesel - 0 applicable rules found
# User blackisthe - 6 applicable rules found
# User bladehelm - 5 applicable rules found
# User blakebradshaw - 0 applicable rules found
# User blakeoty85 - 3 applicable rules found
# User blakeshafer91 - 0 applicable rules found
# User blaketourville - 1 applicable rules found
# User blakezed - 14 applicable rules found
# User blaze_boy - 0 applicable rules found
# User bleachedflies - 0 applicable rules found
# User bleeed - 14 applicable rules found
# User blkwatcher - 0 applicable rules found
# User blockup - 2 applicable rules found
# User blonde_ape - 9 applicable rules found
# User blooberthebee - 11 applicable rules found
# User bloodykisses - 2 applicable rules found
# User bloodyknucklss - 1 applicable rules found
# User bluberysmles - 0 applicable rules found
# User bluemovies88 - 0 applicable rules found
# User blueraptor - 12 applicable rules found
# User bluerray - 16 applicable rules found
# User bluetheraptor1 - 1 applicable rules found
# User blueynotthedog - 2 applicable rules found
# User blumxon - 4 applicable rules found
# User blurryo - 1 applicable rules found
# User bmart17 - 0 applicable rules found
# User bmoviecult - 1 applicable rules found
# User bobatthemovies - 12 applicable rules found
# User bobbeyonce - 11 applicable rules found
# User bobcashill - 0 applicable rules found
# User bobdyboo - 6 applicable rules found
# User bobganoush - 4 applicable rules found
# User bobhoveyga - 0 applicable rules found
# User bobsama - 0 applicable rules found
# User bocamoonia - 0 applicable rules found
# User bodytalky - 0 applicable rules found
# User bogart1942 - 1 applicable rules found
# User bogdi22 - 5 applicable rules found
# User bohemianyankee - 0 applicable rules found
# User boi_bumba - 3 applicable rules found
# User boingo03 - 0 applicable rules found
# User bojustbo - 2 applicable rules found
# User bolhitasemvolta - 0 applicable rules found
# User bondfan03 - 0 applicable rules found
# User bonegripper - 0 applicable rules found
# User boobertscoobert - 4 applicable rules found
# User booboobaby11 - 0 applicable rules found
# User boodado1 - 0 applicable rules found
# User boodee - 2 applicable rules found
# User bookofrasimp - 0 applicable rules found
# User bookshelfjunk - 2 applicable rules found
# User bookstorethor - 0 applicable rules found
# User boomerpitw - 0 applicable rules found
# User boommikey - 0 applicable rules found
# User boosphinx - 1 applicable rules found
# User bootstrap96 - 0 applicable rules found
# User bootygarland - 0 applicable rules found
# User bostonjon - 0 applicable rules found
# User bowie_who - 0 applicable rules found
# User boyaharumichi01 - 1 applicable rules found
# User bozodeathgod - 2 applicable rules found
# User bpadilla - 0 applicable rules found
# User bradenda - 17 applicable rules found
# User brady_brauny - 2 applicable rules found
# User braidsnglasses2 - 0 applicable rules found
# User brainofblood - 1 applicable rules found
# User branditocarp - 0 applicable rules found
# User brandocalreezy - 0 applicable rules found
# User brandon_wiberg - 17 applicable rules found
# User brandonkell - 10 applicable rules found
# User brands42 - 1 applicable rules found
# User brantino - 0 applicable rules found
# User braydn - 0 applicable rules found
# User braydoon - 6 applicable rules found
# User breachyrockett - 0 applicable rules found
# User breadddmann - 0 applicable rules found
# User brechtdfrt - 0 applicable rules found
# User brendanfklein - 0 applicable rules found
# User brendanmleonard - 0 applicable rules found
# User brent_ - 0 applicable rules found
# User brettandjb - 0 applicable rules found
# User brettbuster - 11 applicable rules found
# User brettgoldstein - 0 applicable rules found
# User brettlv5506 - 0 applicable rules found
# User brettshort - 5 applicable rules found
# User brewer82091 - 1 applicable rules found
# User brianbonanza - 0 applicable rules found
# User brianj14 - 5 applicable rules found
# User brianloring - 2 applicable rules found
# User brianwestermann - 0 applicable rules found
# User briary - 0 applicable rules found
# User brick_headed - 3 applicable rules found
# User bridgeswilson - 1 applicable rules found
# User brightboy87 - 0 applicable rules found
# User britfitz - 0 applicable rules found
# User brnny11 - 4 applicable rules found
# User brodie181 - 1 applicable rules found
# User brodiey - 14 applicable rules found
# User brody213 - 3 applicable rules found
# User brontosaura - 0 applicable rules found
# User brucerogers - 0 applicable rules found
# User brucewayne1989 - 2 applicable rules found
# User bruhvania - 6 applicable rules found
# User brunino11 - 2 applicable rules found
# User brunocordeiro14 - 0 applicable rules found
# User brusquetagris - 1 applicable rules found
# User bruupru - 0 applicable rules found
# User brxndy - 16 applicable rules found
# User bryan_23 - 0 applicable rules found
# User brycejqadams - 2 applicable rules found
# User bryk - 0 applicable rules found
# User brynz - 3 applicable rules found
# User brysquatch - 0 applicable rules found
# User bsgvit - 0 applicable rules found
# User bsilaas - 0 applicable rules found
# User bsilva91 - 8 applicable rules found
# User bstrat - 0 applicable rules found
# User bthningmn - 3 applicable rules found
# User bubbles1669 - 0 applicable rules found
# User bubbyo - 0 applicable rules found
# User buckfernandez - 0 applicable rules found
# User buddyrevell - 0 applicable rules found
# User budindepunk - 0 applicable rules found
# User buho718 - 6 applicable rules found
# User buketozbkk - 0 applicable rules found
# User bulla85dow - 1 applicable rules found
# User bulletproofqpid - 2 applicable rules found
# User bumbumboris - 0 applicable rules found
# User bumpeemonkee - 3 applicable rules found
# User burakgoral - 0 applicable rules found
# User burgio - 1 applicable rules found
# User buriedinblurays - 15 applicable rules found
# User burjz - 2 applicable rules found
# User burks008 - 0 applicable rules found
# User burnsynyy - 1 applicable rules found
# User bursteardrum - 1 applicable rules found
# User burt_burlington - 15 applicable rules found
# User burycourt - 1 applicable rules found
# User butkica - 1 applicable rules found
# User butler19911991 - 0 applicable rules found
# User butlerman547 - 0 applicable rules found
# User buttholesurfer - 0 applicable rules found
# User buttress - 9 applicable rules found
# User buzzcutbf - 1 applicable rules found
# User buzzkillzine - 1 applicable rules found
# User bvtchcrafts - 4 applicable rules found
# User bybibia - 0 applicable rules found
# User bzimmer - 0 applicable rules found
# User c004epoch89 - 0 applicable rules found
# User c172heavy - 0 applicable rules found
# User c_elegans - 0 applicable rules found
# User c_strover - 0 applicable rules found
# User c_the_lyn - 0 applicable rules found
# User caaaaake - 0 applicable rules found
# User caarlana - 1 applicable rules found
# User cabanochi - 10 applicable rules found
# User cademacleanyt - 0 applicable rules found
# User cadepospisil - 0 applicable rules found
# User cailee_liu - 1 applicable rules found
# User caioramalhow - 2 applicable rules found
# User cait1712 - 1 applicable rules found
# User calbertjohn - 5 applicable rules found
# User caldinn - 1 applicable rules found
# User calebabel - 1 applicable rules found
# User cali_b - 0 applicable rules found
# User callisto - 0 applicable rules found
# User callmeshera - 0 applicable rules found
# User callummoviefan - 9 applicable rules found
# User callumthurs - 1 applicable rules found
# User calrisia - 0 applicable rules found
# User calzadaceber - 4 applicable rules found
# User cam_watson - 0 applicable rules found
# User cambnewton - 10 applicable rules found
# User cambriino - 2 applicable rules found
# User cameraman - 0 applicable rules found
# User camerondanielle - 1 applicable rules found
# User cameronwjohnson - 0 applicable rules found
# User cameryn468 - 1 applicable rules found
# User camillesanks - 0 applicable rules found
# User camilletsang - 2 applicable rules found
# User camorayn - 1 applicable rules found
# User camveitch - 1 applicable rules found
# User canagh - 3 applicable rules found
# User cantankerouscal - 0 applicable rules found
# User caoimheforan - 0 applicable rules found
# User caosrules - 0 applicable rules found
# User capa582 - 0 applicable rules found
# User capbean - 0 applicable rules found
# User capitanpedales - 11 applicable rules found
# User capivara1101 - 5 applicable rules found
# User capriccio - 0 applicable rules found
# User captaindickson - 7 applicable rules found
# User captaintrailer - 0 applicable rules found
# User captbranbran - 14 applicable rules found
# User capuceta - 1 applicable rules found
# User caralynnex - 0 applicable rules found
# User caramel11 - 0 applicable rules found
# User caramol - 0 applicable rules found
# User carcrashh - 14 applicable rules found
# User carelesspine - 1 applicable rules found
# User carithlee - 1 applicable rules found
# User carlaraptor - 1 applicable rules found
# User carlhinchman - 17 applicable rules found
# User carlish - 0 applicable rules found
# User carlisun - 0 applicable rules found
# User carlluis - 0 applicable rules found
# User carlmtn - 0 applicable rules found
# User carlos954 - 0 applicable rules found
# User carlospires - 2 applicable rules found
# User carlosquintao - 0 applicable rules found
# User carlsanm - 2 applicable rules found
# User carnickl - 0 applicable rules found
# User carolina_campos - 0 applicable rules found
# User carolineas__ - 0 applicable rules found
# User carolnobrega19 - 0 applicable rules found
# User carolyn_k - 0 applicable rules found
# User carrotlime - 3 applicable rules found
# User carrotsick - 0 applicable rules found
# User carterhaskins - 0 applicable rules found
# User carthur1 - 0 applicable rules found
# User cartsgh - 0 applicable rules found
# User caseyweider - 0 applicable rules found
# User casinohille - 9 applicable rules found
# User casmurphy - 0 applicable rules found
# User casperella - 0 applicable rules found
# User cassidy_golden - 0 applicable rules found
# User cassiekavanagh - 4 applicable rules found
# User catboycount - 0 applicable rules found
# User catbreadd - 1 applicable rules found
# User catfox99 - 0 applicable rules found
# User cathoderituals - 2 applicable rules found
# User cathrin2405 - 0 applicable rules found
# User cavershamragu - 0 applicable rules found
# User cavolon - 0 applicable rules found
# User caylon - 3 applicable rules found
# User cbarky79 - 0 applicable rules found
# User cbear3922 - 4 applicable rules found
# User cberlin98 - 1 applicable rules found
# User cbf - 0 applicable rules found
# User cbruce - 4 applicable rules found
# User cc444 - 0 applicable rules found
# User ccbaxter - 0 applicable rules found
# User ccrime - 0 applicable rules found
# User cdelross - 2 applicable rules found
# User cdolezal - 0 applicable rules found
# User cecesherman - 0 applicable rules found
# User ceci17 - 0 applicable rules found
# User cedric_diggory - 5 applicable rules found
# User ceest - 0 applicable rules found
# User cejei - 15 applicable rules found
# User celicc - 3 applicable rules found
# User celluloidqueer - 0 applicable rules found
# User celluloidsavant - 0 applicable rules found
# User celsi - 1 applicable rules found
# User cerealatmidnite - 0 applicable rules found
# User cerses - 0 applicable rules found
# User cershmer - 10 applicable rules found
# User certifiedeghoul - 4 applicable rules found
# User ceruleanlit - 0 applicable rules found
# User ceryswilson - 2 applicable rules found
# User cesarcalaway - 0 applicable rules found
# User cfbilly - 2 applicable rules found
# User cfquirke - 0 applicable rules found
# User cgalazka92 - 3 applicable rules found
# User ch8wl0c0 - 1 applicable rules found
# User chaalnrt05 - 0 applicable rules found
# User chaarlie_ehn - 1 applicable rules found
# User chacha41200 - 3 applicable rules found
# User chadman - 0 applicable rules found
# User chainstain - 2 applicable rules found
# User chajunhos - 0 applicable rules found
# User chambacat - 17 applicable rules found
# User champ83 - 1 applicable rules found
# User champollion - 4 applicable rules found
# User chancepryor - 0 applicable rules found
# User chanelazine - 6 applicable rules found
# User chanelliewellie - 2 applicable rules found
# User chany_ms - 4 applicable rules found
# User chaospo - 0 applicable rules found
# User charleddy - 1 applicable rules found
# User charliebrod005 - 0 applicable rules found
# User charliecoslett - 0 applicable rules found
# User charliecummings - 6 applicable rules found
# User charskiii - 18 applicable rules found
# User chasemonkey - 0 applicable rules found
# User chbae - 0 applicable rules found
# User chebac193 - 6 applicable rules found
# User cheerios0921 - 0 applicable rules found
# User cheeseandtoxins - 0 applicable rules found
# User cheesymongoose - 1 applicable rules found
# User chef_youssef - 0 applicable rules found
# User chelsalexn - 0 applicable rules found
# User chenchen - 0 applicable rules found
# User cherinhas - 5 applicable rules found
# User chernosotenets - 1 applicable rules found
# User chesquik - 4 applicable rules found
# User chiaranara - 0 applicable rules found
# User chibisaurus - 1 applicable rules found
# User chicargill - 0 applicable rules found
# User chickennuggetsr - 0 applicable rules found
# User chickenperm - 0 applicable rules found
# User chiefwiggum - 1 applicable rules found
# User chilledtortoise - 0 applicable rules found
# User chillz89 - 0 applicable rules found
# User chime_ - 4 applicable rules found
# User chimiwtf - 15 applicable rules found
# User chinenyenwa - 0 applicable rules found
# User chio666 - 0 applicable rules found
# User chiphall - 0 applicable rules found
# User chloe1 - 0 applicable rules found
# User chloehoperyder - 1 applicable rules found
# User chocochexmix - 0 applicable rules found
# User chocolatefinger - 1 applicable rules found
# User chompslewis - 0 applicable rules found
# User chorake - 1 applicable rules found
# User chowder077 - 0 applicable rules found
# User chr1s_gramajo - 11 applicable rules found
# User chri06 - 1 applicable rules found
# User chriseq - 0 applicable rules found
# User chrisew - 0 applicable rules found
# User chrisgascan - 0 applicable rules found
# User chrishelgie - 2 applicable rules found
# User chrismakesfilm - 0 applicable rules found
# User chrisorc - 10 applicable rules found
# User chrisovens - 3 applicable rules found
# User chrispratts_mom - 0 applicable rules found
# User christ_air_x - 10 applicable rules found
# User christinanoir - 1 applicable rules found
# User chromeselected - 0 applicable rules found
# User chryysmad - 0 applicable rules found
# User chubbs_420 - 10 applicable rules found
# User chucknora - 0 applicable rules found
# User chudsworth - 1 applicable rules found
# User chuni - 13 applicable rules found
# User cigbubbles - 1 applicable rules found
# User cine_matic - 2 applicable rules found
# User cinebool - 0 applicable rules found
# User cineemac - 0 applicable rules found
# User cinema_beltrade - 0 applicable rules found
# User cinema_snobb - 1 applicable rules found
# User cinema_strikes - 0 applicable rules found
# User cinemabyjulia - 3 applicable rules found
# User cinemac1ty - 1 applicable rules found
# User cinemack89 - 7 applicable rules found
# User cinemakellan - 8 applicable rules found
# User cinemanax - 0 applicable rules found
# User cinemanicon - 0 applicable rules found
# User cinemaroni - 0 applicable rules found
# User cinemaserf - 3 applicable rules found
# User cinemat2020 - 1 applicable rules found
# User cinematic_ally - 4 applicable rules found
# User cinematicbrix - 0 applicable rules found
# User cinemay - 0 applicable rules found
# User cinemily - 0 applicable rules found
# User cinemurat - 0 applicable rules found
# User cinemuzer - 0 applicable rules found
# User cineparasitx - 0 applicable rules found
# User cinephile_alex - 0 applicable rules found
# User cinephileadict - 0 applicable rules found
# User cinestreamcast - 0 applicable rules found
# User cinn48 - 1 applicable rules found
# User cinnamonsea - 0 applicable rules found
# User cinquezeri - 0 applicable rules found
# User circleofgoats - 0 applicable rules found
# User citizenryan - 5 applicable rules found
# User citron59 - 0 applicable rules found
# User citygent - 0 applicable rules found
# User civictv49 - 0 applicable rules found
# User ckckred - 4 applicable rules found
# User ckosinskiii - 4 applicable rules found
# User claire95 - 1 applicable rules found
# User clairecray - 1 applicable rules found
# User clairegrylls - 0 applicable rules found
# User claireitin - 0 applicable rules found
# User clairej0 - 0 applicable rules found
# User clairemole - 1 applicable rules found
# User clara_x - 1 applicable rules found
# User clarissea - 2 applicable rules found
# User classicalgenz - 0 applicable rules found
# User classiclyours - 0 applicable rules found
# User classicmaterial - 0 applicable rules found
# User claudia_sanchez - 5 applicable rules found
# User claughton - 5 applicable rules found
# User claycalv - 2 applicable rules found
# User clayha - 0 applicable rules found
# User cldn - 0 applicable rules found
# User clebi - 3 applicable rules found
# User clemeentine - 1 applicable rules found
# User clemrialto - 3 applicable rules found
# User cletusvandamm - 1 applicable rules found
# User clevercubed - 1 applicable rules found
# User cloacacarnage - 0 applicable rules found
# User clockula - 1 applicable rules found
# User clorazepunk - 1 applicable rules found
# User closeddoor - 0 applicable rules found
# User cloudiar1 - 0 applicable rules found
# User cloudyycolfer - 0 applicable rules found
# User clowngoblin - 1 applicable rules found
# User clrncgmb - 0 applicable rules found
# User clumsy_kaiju - 0 applicable rules found
# User clumsymachine81 - 0 applicable rules found
# User cmchen - 0 applicable rules found
# User cmncln - 0 applicable rules found
# User cnb - 0 applicable rules found
# User co_villeneuve - 10 applicable rules found
# User coarey - 1 applicable rules found
# User cobb - 0 applicable rules found
# User cobbb - 1 applicable rules found
# User coblabgd - 0 applicable rules found
# User codycvlp - 0 applicable rules found
# User codyforhire - 2 applicable rules found
# User coffeestomach - 4 applicable rules found
# User coffin_joe - 3 applicable rules found
# User cogerson - 0 applicable rules found
# User coletone3 - 2 applicable rules found
# User colin_browning - 1 applicable rules found
# User colin_matzkows - 3 applicable rules found
# User colinhilding - 12 applicable rules found
# User colinj96 - 0 applicable rules found
# User colinmcdonnell - 1 applicable rules found
# User colinmcev - 6 applicable rules found
# User collinjtn - 1 applicable rules found
# User collinodonnell - 0 applicable rules found
# User coloredchess - 0 applicable rules found
# User coloredmaps - 3 applicable rules found
# User colorfilms - 10 applicable rules found
# User comixzombie - 2 applicable rules found
# User comme_la_fleur - 1 applicable rules found
# User commitarsyn - 0 applicable rules found
# User comrade_yui - 0 applicable rules found
# User comrie - 0 applicable rules found
# User conan85 - 0 applicable rules found
# User conifer - 0 applicable rules found
# User conisbeee - 0 applicable rules found
# User connermusic - 8 applicable rules found
# User connoisseur124 - 2 applicable rules found
# User connordenney - 0 applicable rules found
# User connorewart - 2 applicable rules found
# User connorp368 - 1 applicable rules found
# User connorpurnell - 22 applicable rules found
# User connorsmyth - 1 applicable rules found
# User conordowling - 0 applicable rules found
# User constantellis - 0 applicable rules found
# User constantin_psc - 0 applicable rules found
# User contracampo100 - 1 applicable rules found
# User contrazoompod - 1 applicable rules found
# User cookinganna - 0 applicable rules found
# User coolabedfilms - 2 applicable rules found
# User cooldudetm - 0 applicable rules found
# User cooljavon16 - 4 applicable rules found
# User coolkoko - 11 applicable rules found
# User coolstevenn - 0 applicable rules found
# User cooperander_ - 0 applicable rules found
# User coose - 16 applicable rules found
# User copperbirdman - 0 applicable rules found
# User copperkobold - 1 applicable rules found
# User copyablefish863 - 0 applicable rules found
# User corii - 0 applicable rules found
# User corncake - 0 applicable rules found
# User corndog007 - 0 applicable rules found
# User corporaltanner - 0 applicable rules found
# User cortes - 0 applicable rules found
# User cortinhas - 1 applicable rules found
# User cory_f - 0 applicable rules found
# User coryk - 3 applicable rules found
# User cosmickavi - 0 applicable rules found
# User cosmicmonster - 7 applicable rules found
# User cosmicthing - 2 applicable rules found
# User count_nolaf - 0 applicable rules found
# User cowboy_rivers - 2 applicable rules found
# User cowboylikeida - 0 applicable rules found
# User cowboyrin - 1 applicable rules found
# User cowgirlavar - 1 applicable rules found
# User cowtools - 0 applicable rules found
# User coyfish - 1 applicable rules found
# User coyotefugly - 2 applicable rules found
# User cozzaprods - 8 applicable rules found
# User cp_podcast - 2 applicable rules found
# User cpgod - 1 applicable rules found
# User cr0w1ey - 0 applicable rules found
# User craddocklcfc - 1 applicable rules found
# User cradleofpandora - 2 applicable rules found
# User craftswi - 1 applicable rules found
# User craig_tanner89 - 10 applicable rules found
# User crankyasianman - 0 applicable rules found
# User crathkn - 7 applicable rules found
# User crawleyjn - 2 applicable rules found
# User crazyfist66 - 2 applicable rules found
# User crazysalart - 0 applicable rules found
# User creakycoffines - 1 applicable rules found
# User creativedrizzle - 0 applicable rules found
# User crimsin - 2 applicable rules found
# User cringayrat - 3 applicable rules found
# ...
# User tubamirum - 0 applicable rules found
# User tuch - 0 applicable rules found
# User tuculoabierto - 1 applicable rules found
# User tuhdumta - 11 applicable rules found
# User tulsa - 0 applicable rules found
# User tuomo95 - 1 applicable rules found
# User tutlu - 1 applicable rules found
# User tvansantana - 2 applicable rules found
# User twakko - 0 applicable rules found
# User twenty4e - 3 applicable rules found
# User twentymilesleft - 2 applicable rules found
# User twiii - 0 applicable rules found
# User twilightbyboa - 1 applicable rules found
# User twogreatships - 0 applicable rules found
# User twotubman - 0 applicable rules found
# User twrantino - 0 applicable rules found
# User tycio - 7 applicable rules found
# User tyclair - 0 applicable rules found
# User tylerdurden36 - 0 applicable rules found
# User tylergfoster - 8 applicable rules found
# User tylertadeo - 0 applicable rules found
# User tynanbrooks - 0 applicable rules found
# User tyson_daniels - 0 applicable rules found
# User tytdreviews - 2 applicable rules found
# User ufukkurt - 1 applicable rules found
# User ugleegoff - 2 applicable rules found
# User uh_abbie - 0 applicable rules found
# User uhhhpollo - 0 applicable rules found
# User uhworldalone - 0 applicable rules found
# User ukiyaseed - 1 applicable rules found
# User ultrapandora - 4 applicable rules found
# User un7ption - 0 applicable rules found
# User unansweredshoe - 5 applicable rules found
# User unbehauden - 3 applicable rules found
# User unbeheld - 2 applicable rules found
# User unclefarter5 - 2 applicable rules found
# User undeadcomicsinc - 0 applicable rules found
# User underalls - 0 applicable rules found
# User underneath75 - 0 applicable rules found
# User unk1llable - 20 applicable rules found
# User unlocalh - 1 applicable rules found
# User urfav_nova - 0 applicable rules found
# User urislotnik - 0 applicable rules found
# User ursocoobrewster - 2 applicable rules found
# User useless_desk - 0 applicable rules found
# User user817600 - 0 applicable rules found
# User usernicole - 1 applicable rules found
# User utomi01 - 0 applicable rules found
# User utternyms - 0 applicable rules found
# User vaction - 0 applicable rules found
# User vadalma1970 - 0 applicable rules found
# User vaderjenah - 4 applicable rules found
# User vagelisvitsikas - 0 applicable rules found
# User vaibhavvijay - 1 applicable rules found
# User val_the_filmguy - 5 applicable rules found
# User valantinellie - 0 applicable rules found
# User valchicampana - 0 applicable rules found
# User valenttts - 16 applicable rules found
# User valkyrie244 - 2 applicable rules found
# User valnos - 2 applicable rules found
# User valtazar - 0 applicable rules found
# User vamos - 1 applicable rules found
# User vampierusboy - 0 applicable rules found
# User vampirelungs - 2 applicable rules found
# User vanderfilm - 0 applicable rules found
# User vanessaceline - 0 applicable rules found
# User vanillasunrise - 14 applicable rules found
# User vanish4d - 0 applicable rules found
# User vanslater - 1 applicable rules found
# User varla - 0 applicable rules found
# User varunoakbhakay - 0 applicable rules found
# User vawaterfield - 2 applicable rules found
# User vayolet - 0 applicable rules found
# User vby199 - 0 applicable rules found
# User ved_is_ded - 0 applicable rules found
# User veeyalowbows - 1 applicable rules found
# User vegavegavega - 0 applicable rules found
# User vegim11 - 2 applicable rules found
# User velcreiro - 1 applicable rules found
# User velfgren - 0 applicable rules found
# User velkeyta - 0 applicable rules found
# User velveetahead - 0 applicable rules found
# User vennice - 0 applicable rules found
# User vennilave - 0 applicable rules found
# User ver_joseff - 1 applicable rules found
# User vernerdauntson - 1 applicable rules found
# User veroarroyo - 0 applicable rules found
# User veronicalv - 1 applicable rules found
# User versace_cologne - 14 applicable rules found
# User verycoolpersn - 1 applicable rules found
# User verymary - 4 applicable rules found
# User veryunknown - 0 applicable rules found
# User vetaiz - 0 applicable rules found
# User vezlae - 8 applicable rules found
# User vhsdvdandbeyond - 4 applicable rules found
# User vhstapes - 14 applicable rules found
# User vhsvandal - 0 applicable rules found
# User viaaax - 0 applicable rules found
# User viatoons_99 - 0 applicable rules found
# User vibolzzoni - 1 applicable rules found
# User vibrantflame85 - 0 applicable rules found
# User vic_parratt - 0 applicable rules found
# User vicctinho - 3 applicable rules found
# User vicente28 - 0 applicable rules found
# User vichart_1980 - 0 applicable rules found
# User vick_tr - 0 applicable rules found
# User vickytogisa - 2 applicable rules found
# User victorbergvaall - 2 applicable rules found
# User victoriaxlouise - 9 applicable rules found
# User videodrome71 - 1 applicable rules found
# User videomanngizmo - 0 applicable rules found
# User vidiotbox - 2 applicable rules found
# User vidof - 1 applicable rules found
# User vijayc12u - 2 applicable rules found
# User vijaysegharan - 0 applicable rules found
# User vimoga - 7 applicable rules found
# User vincemale - 0 applicable rules found
# User vincentrenard - 14 applicable rules found
# User viniciusog - 0 applicable rules found
# User vinnyboombots88 - 0 applicable rules found
# User vintagegrunge - 1 applicable rules found
# User vinyl_06 - 1 applicable rules found
# User viqtorias - 2 applicable rules found
# User virumquelibris - 0 applicable rules found
# User vishant - 2 applicable rules found
# User vishesh_kumar - 0 applicable rules found
# User vitorforte - 0 applicable rules found
# User vitoriaguilar - 0 applicable rules found
# User vituxpy - 0 applicable rules found
# User vivianhalladay - 0 applicable rules found
# User vkiss - 1 applicable rules found
# User vlegallois - 0 applicable rules found
# User vllort - 0 applicable rules found
# User vmann - 15 applicable rules found
# User vnatasza - 1 applicable rules found
# User vnpryor - 0 applicable rules found
# User voeye - 0 applicable rules found
# User voidmamma - 1 applicable rules found
# User volgaragon - 0 applicable rules found
# User voltron2005 - 8 applicable rules found
# User vomltgore - 0 applicable rules found
# User vonnziola - 1 applicable rules found
# User vqunm - 1 applicable rules found
# User vrhunska - 0 applicable rules found
# User vshz - 1 applicable rules found
# User vsoaeq - 2 applicable rules found
# User vson - 0 applicable rules found
# User vulgarbunny - 0 applicable rules found
# User vuraxis - 1 applicable rules found
# User vuvivator - 0 applicable rules found
# User vv - 1 applicable rules found
# User wabbit - 0 applicable rules found
# User wabunguh - 0 applicable rules found
# User wadesowers - 0 applicable rules found
# User wagnergpnc - 11 applicable rules found
# User waigo - 0 applicable rules found
# User walker_cates - 2 applicable rules found
# User walkeranthony - 1 applicable rules found
# User walkerct - 2 applicable rules found
# User walterburns76 - 0 applicable rules found
# User walthersorsa - 7 applicable rules found
# User waltz3 - 1 applicable rules found
# User wamespno - 1 applicable rules found
# User wanness - 2 applicable rules found
# User warpedjude - 1 applicable rules found
# User warren82 - 0 applicable rules found
# User warrensikes - 0 applicable rules found
# User warungsop28 - 2 applicable rules found
# User washablemarkers - 3 applicable rules found
# User washington - 0 applicable rules found
# User wastelander997 - 1 applicable rules found
# User wastelandscribe - 4 applicable rules found
# User waterwitch - 14 applicable rules found
# User waveofteeth - 4 applicable rules found
# User wbar - 1 applicable rules found
# User wbrasseau - 0 applicable rules found
# User wdwhsf - 1 applicable rules found
# User webio - 4 applicable rules found
# User websitedotcool - 0 applicable rules found
# User wee_see_toe - 1 applicable rules found
# User weebus12 - 2 applicable rules found
# User weehunk - 0 applicable rules found
# User weeshuggy - 1 applicable rules found
# User weessm - 5 applicable rules found
# User weh8harry - 1 applicable rules found
# User wehateian - 1 applicable rules found
# User weirdfishes3 - 0 applicable rules found
# User weldonlmarshall - 3 applicable rules found
# User welseym - 0 applicable rules found
# User westhelara - 6 applicable rules found
# User wfterstrode - 11 applicable rules found
# User whatisthiswint - 1 applicable rules found
# User whatthewill - 1 applicable rules found
# User whatyewatchin - 2 applicable rules found
# User whitemarigold - 0 applicable rules found
# User whitewolf998 - 3 applicable rules found
# User whitey315 - 9 applicable rules found
# User whyfloat - 0 applicable rules found
# User whyjuaum - 4 applicable rules found
# User whyyu95 - 1 applicable rules found
# User wibney - 0 applicable rules found
# User wickedjaws - 0 applicable rules found
# User widdowquinn - 1 applicable rules found
# User wildbillsghost - 0 applicable rules found
# User wilddaisies - 0 applicable rules found
# User wildwestfall - 1 applicable rules found
# User wilfredlucas - 2 applicable rules found
# User will_bel - 0 applicable rules found
# User willcarper - 0 applicable rules found
# User willend96 - 0 applicable rules found
# User william412 - 0 applicable rules found
# User williamfaeleith - 0 applicable rules found
# User willis787 - 3 applicable rules found
# User willkrug - 12 applicable rules found
# User willmiller - 15 applicable rules found
# User willowsfields - 1 applicable rules found
# User willprososki - 2 applicable rules found
# User willremmers - 0 applicable rules found
# User willtatertot - 1 applicable rules found
# User willtopower - 1 applicable rules found
# User willyboy22 - 15 applicable rules found
# User willyp22 - 0 applicable rules found
# User windowpained - 4 applicable rules found
# User winonaboynton - 0 applicable rules found
# User winsnesj - 3 applicable rules found
# User winthewonderboy - 1 applicable rules found
# User wippyz - 0 applicable rules found
# User wiscomovieguru - 1 applicable rules found
# User witchbail - 0 applicable rules found
# User witchymethyst - 0 applicable rules found
# User wixpix - 0 applicable rules found
# User wjlowe - 0 applicable rules found
# User wkirab - 0 applicable rules found
# User wmboyle4 - 0 applicable rules found
# User wogong - 2 applicable rules found
# User wokaaa - 1 applicable rules found
# User wolfmanstevie - 2 applicable rules found
# User wolverine551 - 5 applicable rules found
# User wolverita - 1 applicable rules found
# User wonggifs - 1 applicable rules found
# User woods_man - 1 applicable rules found
# User woomann - 1 applicable rules found
# User wootini - 17 applicable rules found
# User worcestermobley - 0 applicable rules found
# User wouterdp6 - 0 applicable rules found
# User wqz - 0 applicable rules found
# User wrenster - 1 applicable rules found
# User wsumietosuper - 3 applicable rules found
# User wtssfi - 0 applicable rules found
# User wujtah - 0 applicable rules found
# User wvolny - 1 applicable rules found
# User wwmck - 6 applicable rules found
# User wwwiillll - 15 applicable rules found
# User wyajj_11l - 1 applicable rules found
# User wyattzelle - 23 applicable rules found
# User wykah - 1 applicable rules found
# User xakbarb - 12 applicable rules found
# User xandermcc - 0 applicable rules found
# User xavisanchezpons - 1 applicable rules found
# User xclryu - 0 applicable rules found
# User xebeche - 0 applicable rules found
# User xego - 0 applicable rules found
# User xeivious - 9 applicable rules found
# User xenomorphz - 10 applicable rules found
# User xenovir - 0 applicable rules found
# User xephraim - 1 applicable rules found
# User xeroxnat - 8 applicable rules found
# User xmccola - 5 applicable rules found
# User xmlcrimes - 0 applicable rules found
# User xnavonod9x - 0 applicable rules found
# User xolbe2 - 0 applicable rules found
# User xorec1942 - 1 applicable rules found
# User xoxohme - 1 applicable rules found
# User xoxovictor - 0 applicable rules found
# User xunguito - 0 applicable rules found
# User xxmoviehoes - 1 applicable rules found
# User xyungxlechex - 1 applicable rules found
# User y1git - 0 applicable rules found
# User y_mama - 15 applicable rules found
# User ya_boi_joe - 1 applicable rules found
# User yaelpollie - 0 applicable rules found
# User yagata - 1 applicable rules found
# User yahooserious - 4 applicable rules found
# User yakamazola - 0 applicable rules found
# User yakko2004 - 1 applicable rules found
# User yam_sd - 0 applicable rules found
# User yanicelegrand - 5 applicable rules found
# User yarjka - 0 applicable rules found
# User yarsvent - 0 applicable rules found
# User yasdarosita - 2 applicable rules found
# User yasmecchi - 2 applicable rules found
# User yasmynplanet - 4 applicable rules found
# User yasysminn - 1 applicable rules found
# User yatate_hajime - 0 applicable rules found
# User yeahiamvictor - 0 applicable rules found
# User yeaitscrab - 1 applicable rules found
# User yebard - 0 applicable rules found
# User yellacraion - 9 applicable rules found
# User yellowpurples - 25 applicable rules found
# User yeoj1214 - 14 applicable rules found
# User yippee3 - 0 applicable rules found
# User yitzinema - 3 applicable rules found
# User yixinwang - 0 applicable rules found
# User yldarb - 0 applicable rules found
# User ymtbeloved - 1 applicable rules found
# User yodigg23 - 1 applicable rules found
# User yoghurtsgirl - 1 applicable rules found
# User yokinney - 14 applicable rules found
# User yonyorklad - 2 applicable rules found
# User yoshifan456 - 0 applicable rules found
# User yosoyaustere - 0 applicable rules found
# User you_in_reverse - 0 applicable rules found
# User youandicannabis - 0 applicable rules found
# User youngnacho990 - 5 applicable rules found
# User youngnastyman88 - 3 applicable rules found
# User yourmkebeers - 17 applicable rules found
# User yourpalaugie - 0 applicable rules found
# User yozze - 0 applicable rules found
# User yrvhere - 0 applicable rules found
# User yuanfang - 0 applicable rules found
# User yuciee - 0 applicable rules found
# User yumboyumboyumbo - 0 applicable rules found
# User yurapam - 0 applicable rules found
# User yusufpiskin - 0 applicable rules found
# User yvng_oldhead - 1 applicable rules found
# User yvonne_aaf - 9 applicable rules found
# User yyhamburgers - 14 applicable rules found
# User zacharybinx - 0 applicable rules found
# User zachj0923 - 0 applicable rules found
# User zachsullentrup - 2 applicable rules found
# User zafisher94 - 5 applicable rules found
# User zagaa - 1 applicable rules found
# User zaharayeah - 0 applicable rules found
# User zaiydo - 4 applicable rules found
# User zakk1234 - 2 applicable rules found
# User zanesimon - 0 applicable rules found
# User zanistos - 0 applicable rules found
# User zaque21 - 0 applicable rules found
# User zara926 - 0 applicable rules found
# User zaraaaaaaa - 0 applicable rules found
# User zaragrid - 5 applicable rules found
# User zaraismail - 3 applicable rules found
# User zavero - 2 applicable rules found
# User zdravomacko - 0 applicable rules found
# User zdsnabes - 0 applicable rules found
# User zeddazogenau - 0 applicable rules found
# User zeeshanfilms - 1 applicable rules found
# User zeppomarxist - 0 applicable rules found
# User zeroka15 - 1 applicable rules found
# User zeromantis - 3 applicable rules found
# User zettt - 0 applicable rules found
# User zglow - 1 applicable rules found
# User zhanlong - 0 applicable rules found
# User zieminski - 0 applicable rules found
# User ziglet_mir - 0 applicable rules found
# User zigzag1984 - 0 applicable rules found
# User zingle - 4 applicable rules found
# User zitygonecrazy - 0 applicable rules found
# User zjohnson715 - 1 applicable rules found
# User zktori - 0 applicable rules found
# User zo0m - 9 applicable rules found
# User zodiacbats - 2 applicable rules found
# User zolak - 1 applicable rules found
# User zolidus - 0 applicable rules found
# User zombiefandan - 0 applicable rules found
# User zombiekel - 5 applicable rules found
# User zorwalk - 5 applicable rules found
# User zpierce - 0 applicable rules found
# User zschrr - 8 applicable rules found
# User zt_1 - 3 applicable rules found
# User zugzwanging - 0 applicable rules found
# User zuul67 - 0 applicable rules found
# User zxynxp - 0 applicable rules found
# User zyoiiib - 3 applicable rules found
# User zzyxzaa - 0 applicable rules found
# User zzyzazazz - 0 applicable rules found

# %%
# transform the table
prediction_AR_df = AR_pred.groupby('user_id').agg({'film': lambda x: set(x)}).reset_index().rename(columns={'film':'predicted_items'})

# Final table
# merge recommended table and last watched table
AR_recommended_df = prediction_AR_df.merge(last_watched_df2, how='left',on='user_id')

# %% [markdown]
# ## Evaluation

# %%
# Evalution function
# Function to calculate precision, recall, F1, and accuracy
def calculate_metrics_with_accuracy(df, k):
    results = []
    for _, row in df.iterrows():
        predicted_items = set(row['predicted_items'])
        true_items = set(row['true_items'])
        
        predicted_k = set(list(predicted_items)[:k])
        intersection = predicted_k.intersection(true_items)

        # Precision, Recall, and F1
        precision = len(intersection) / len(predicted_k) if len(predicted_k) > 0 else 0
        recall = len(intersection) / len(true_items) if len(true_items) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        # Accuracy
        total_items = len(predicted_k.union(true_items))
        accuracy = len(intersection) / total_items if total_items > 0 else 0
        
        results.append({
            'user_id': row['user_id'], 
            'precision_at_k': precision, 
            'recall_at_k': recall, 
            'f1_score': f1,
            'accuracy': accuracy
        })

    return pd.DataFrame(results)


def evaluator(df,k=5):
    metrics = calculate_metrics_with_accuracy(df,k)
    # Calculate overall precision, recall, and F1-score by taking the mean
    overall_precision = metrics['precision_at_k'].mean()
    overall_recall = metrics['recall_at_k'].mean()
    overall_f1 = metrics['f1_score'].mean()
    overall_accuracy = metrics['accuracy'].mean()

    # Print the overall accuracy metrics
    print(f"Overall Precision: {overall_precision:.4f}")
    print(f"Overall Recall: {overall_recall:.4f}")
    print(f"Overall F1-Score: {overall_f1:.4f}")
    print(f"Overall Accuracy: {overall_accuracy:.4f}")

# %%
# SVD model
evaluator(svd_recommended_df)
# Out:
# Overall Precision: 0.0006
# Overall Recall: 0.0025
# Overall F1-Score: 0.0009
# Overall Accuracy: 0.0006

# %%
# Similarity
evaluator(similarity_recommended_df)
# Out:
# Overall Precision: 0.0013
# Overall Recall: 0.0046
# Overall F1-Score: 0.0020
# Overall Accuracy: 0.0012

# %%
# Matrix Factorization
print(MF_recommended_df.shape)
evaluator(MF_recommended_df)
# Out:
# (5624, 3)
# Overall Precision: 0.0002
# Overall Recall: 0.0006
# Overall F1-Score: 0.0003
# Overall Accuracy: 0.0002

# %%
# Clustering
print(Clustering_recommended_df.shape)
evaluator(Clustering_recommended_df)
# Out:
# (5624, 3)
# Overall Precision: 0.0032
# Overall Recall: 0.0116
# Overall F1-Score: 0.0048
# Overall Accuracy: 0.0028

# %%
# Association Rule
print(AR_recommended_df.shape)
evaluator(AR_recommended_df)
# Out:
# (421, 3)
# Overall Precision: 0.0000
# Overall Recall: 0.0000
# Overall F1-Score: 0.0000
# Overall Accuracy: 0.0000
